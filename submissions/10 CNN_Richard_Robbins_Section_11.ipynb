# %% [markdown]
# # Lab 10

# %% [markdown]
# #### ``Objectives``
# 1. Implement a CNN to detect diabetic retinopathy (DR) from retina images taken using fundus photography under a variety of imaging conditions
# 2. Improve generalization performance and reduce overfitting using **image transformation** and **data augmentation** techniques
# 3. Tune hyperparameters of the CNN model

# %% [markdown]
# #### ``Motivation``

# %% [markdown]
# Diabetic retinopathy (DR) is an eye condition that  affects blood vessels in the retina. It can cause vision loss and blindness in people who have diabetes. Screening for DR allows earlier and more effective treatment options for millions of people.

# %% [markdown]
# #### ``Data``

# %% [markdown]
# In this assignment you will use a small dataset of retina images (`Download` links: [images](https://drive.google.com/drive/folders/1sdfUC64Un1iwuiHEehcbijxB54OhU_nd?usp=sharing) and [labels](https://drive.google.com/drive/folders/1MOlSJBZg7L1HtG5vHPt77ighRvQaGfDg?usp=sharing)). You will **build** and **train** a **CNN model** to predict whether or not to refer a patient for DR treatment using binarized severity of DR in patients: no referral if {No DR, mild} and referral if {moderate, severe, and proliferate DR}.
#
#
# <u>Note</u>: the original dataset is hosted by Kaggle [[Source]](https://www.kaggle.com/c/aptos2019-blindness-detection/).

# %% [markdown]
# Import the necessary libraries and make sure to replace IMAGE_PATH and LABEL_PATH with the path to the directories where you saved the data.

# %%
# standard
import os
import platform
import random
from time import time

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# plots
import seaborn as sns

# tf and keras
import tensorflow as tf
from keras import layers, models
from tensorflow.keras.preprocessing.image import (
    ImageDataGenerator,
    array_to_img,
    img_to_array,
    load_img,
)

random.seed(2)
# %matplotlib inline

# FILL IN CODE HERE #
IMAGE_PATH = "CNN_images/"  # replace with your path
LABEL_PATH = "CNN_labels/"  # replace with your path

tf.get_logger().setLevel("INFO")
#tf.config.set_visible_devices([], "GPU")

# %% [markdown]
# At this point, you may ask yourself what the best CNN model that fits this data is. First, you will want to read through the data description in Kaggle (see the link to the original dataset above). Understanding what you are working with challenges you to write preprocessing code that uncovers your data's most helpful information.

# %% [markdown]
# ---
# ### Exercise 1 (8 points)

# %% [markdown]
# Read the data description from Kaggle and list (a) the source of images and (b) the labeling procedure.

# %% [markdown]
# *Written answer*:

# %% [markdown]
# **Source of Images**
# [Relevant Excerpts from the Kaggle description.]
#
# Millions of people suffer from diabetic retinopathy, the leading cause of blindness among working aged adults. Aravind Eye Hospital in India hopes to detect and prevent this disease among people living in rural areas where medical screening is difficult to conduct.   Aravind technicians traveled to these rural areas to capture images using fundus photography under a variety of imaging conditions.
#
# **Labeling Procedures**
#
# The images are reviewed by highly trained doctors who rate each image for the severity of diabetic retinopathy on a scale of 0 to 4:
# 1. No diapbetic retinopathy
# 2. Mild diabetic retinopathy
# 3. Severe diabetic retinopathy
# 4. Proliferative diabetic retinopathy (the more advanced stage when the retina starts growing new blood vessels)

# %% [markdown]
# ## Read data

# %% [markdown]
# Let's now explore our dataset. We will start with label inspection and continue with image visualization.

# %%
y = pd.read_csv(LABEL_PATH + "labels.csv")

print("Shape of labels:", y.shape)
print("Unique diagnosis codes:", np.sort(y.diagnosis.unique()))
y.head()
# Out:
# Shape of labels: (200, 2)
# Unique diagnosis codes: [0 1 2 3 4]
#         id_code  diagnosis
# 0  000c1434d8d7          2
# 1  0024cdab0c1e          1
# 2  0083ee8054ee          4
# 3  00a8624548a9          2
# 4  00b74780d31d          2

# %% [markdown]
# There are 200 training images corrresponding to 5 different diabetic retinopathy (DR) diagnosis codes:
#
# * No DR (0)
# * mild (1)
# * moderate (2)
# * severe (3)
# * proliferate DR (4)

# %% [markdown]
# Image inspection:

# %%
# read image
indx = 0
images = []

print("Sample of images in data:")
for idx, img in enumerate(os.listdir(IMAGE_PATH)):
    img = load_img(IMAGE_PATH + img)
    images.append(img)

nrows, ncols = 2, 4  # print first 8 images
f, axs = plt.subplots(nrows, ncols, figsize=(20, 10))
for i in range(nrows):
    for j in range(ncols):
        indx = i * nrows + j
        axs[i, j].imshow(images[indx])
# Out:
# Sample of images in data:

# %% [markdown]
# Like any real-world data set, you can see that these images have different sizes and focus. Later, you will use image transformation and data augmentation techniques to remove some of this variation.

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# The quality of the data determines how well a machine learning algorithm can learn. This section will apply some simple techniques to deal with class imbalance. We will then create training/validation/test datasets and perform image transformation and augmentation.

# %% [markdown]
# ---
# ### Exercise 2 (8 points)

# %% [markdown]
# Graph a histogram for the five classes of DR. Write down the percentage of the largest class in the written answer below.

# %%
# YOUR CODE HERE

y["diagnosis"].hist()
pd.DataFrame()
pd.DataFrame(
    [
        (x, sum(y["diagnosis"] == x), sum(y["diagnosis"] == x) / len(y) * 100)
        for x in np.sort(y["diagnosis"].unique())
    ],
    columns=["label", "count", "percentage"],
)
# Out:
#    label  count  percentage
# 0      0     82        41.0
# 1      1     18         9.0
# 2      2     73        36.5
# 3      3     12         6.0
# 4      4     15         7.5

# %% [markdown]
# *Written answer*:
#
# The largest class is class 0 (no diabetic retinopathy) comprising 41% of the sample population.)

# %% [markdown]
# ---

# %% [markdown]
# `Correct for data imbalance`

# %% [markdown]
# As you can see from the histogram above, our dataset is very imbalanced, which is common in healthcare, and it happens because some diseases are rare. The presence of imbalanced data hampers the detection of rare events as most classification methods implicitly assume a similar occurrence of classes and are designed to maximize the overall classification accuracy.
#
# We will correct for class imbalance in two ways:
#
#   * First, we will binarize the DR diagnosis as follows:
#      - 'no refer' are {No DR, mild}
#      - 'refer' are {Moderate, Severe, Proliferate}
#
#
#   * Second, we'll only take 80 random samples from the 'no refer' class and 80 from the 'refer' class.
#
# It is a crude method to deal with imbalanced data, but it will be good enough for this homework.

# %%
np.random.seed(1234)

no_refer = y[y.diagnosis.isin((0, 1))]
refer = y[y.diagnosis.isin((2, 3, 4))]

# randomly draw 80 images from each classes
temp_no_refer = list(np.random.choice(no_refer.id_code, size=80, replace=False))

temp_refer = list(np.random.choice(refer.id_code, size=80, replace=False))

# %% [markdown]
# Next, we will use the **preprocess_data_part1()** function defined below to generate lists of images and labels (`images_mini` and `y_mini`) based on the values in the temp_no_refer and temp_refer lists.

# %%
def preprocess_data_part1(IMAGE_PATH, LABEL_PATH):
    """ Generate lists of images and labelsbased on temp_no_refer and temp_refer lists
    
    Params:
    -------
    IMAGE_PATH (str): path to directory with images.
    LABEL_PATH (str): path to directory with labels.
    
    Returns:
    --------
    images_mini  (np.ndarray): Images of shape (N, 224, 224, 3)
    y_mini (np.ndarray): Labels of shape (N,)    
    """
    y_mini = []
    images_mini = []

    # create lists of images and labels `images_mini` and `y_mini`
    # based on temp_no_refer and temp_refer selections
    for idx, img in enumerate(os.listdir(IMAGE_PATH)):
        # read labels
        if img.split(".")[0] in temp_no_refer:
            y_mini.append(0)
        elif img.split(".")[0] in temp_refer:
            y_mini.append(1)
        else:
            continue

        # read image
        img = load_img(IMAGE_PATH + img, target_size=(224, 224))

        # transform image to array
        img = img_to_array(img)

        # append to images
        images_mini.append(img)

    # stack images and trasnform to array
    images_mini = np.stack(images_mini)
    y_mini = np.array(y_mini).flatten()

    return images_mini, y_mini

# %%
# generate images and labels based on preprocess_data_part1() function
images_mini, y_mini = preprocess_data_part1(IMAGE_PATH, LABEL_PATH)

print(f"images_mini shape {images_mini.shape}")
print(f"y_mini shape {y_mini.shape}")
# Out:
# images_mini shape (159, 224, 224, 3)
# y_mini shape (159,)

# %% [markdown]
# `Create train/validation/test data` and ``perform image tranformation and augmentation``

# %% [markdown]
# The next step in the data preprocessing part is to split the data into training, validation, and test sets. Once we have these partitions, we will apply image transformation and augmentations.
#
#
# To give you an idea of what image transformation and augmentation do, let's see an example applied to the first image in our mini data.

# %%
tf.random.set_seed(1234)

fig = plt.figure(figsize=(14, 12))

# pull first image from data
image = images_mini[0]

# plot original
ax = fig.add_subplot(1, 5, 1)
ax.imshow(array_to_img(image))
ax.set_title("Original", size=15)

# resize
ax = fig.add_subplot(1, 5, 2)
img_resize = tf.image.resize(image, size=(224, 224))
ax.imshow(array_to_img(img_resize))
ax.set_title("Step 1: Resize", size=15)


# adjust brightness
ax = fig.add_subplot(1, 5, 3)
img_bright = tf.image.adjust_brightness(img_resize, 0.3)
ax.imshow(array_to_img(img_bright))
ax.set_title("Step 2: Brightness", size=15)


# adjust contrast
ax = fig.add_subplot(1, 5, 4)
img_contrast = tf.image.adjust_contrast(img_bright, contrast_factor=3)
ax.imshow(array_to_img(img_contrast))
ax.set_title("Step 3: Contrast", size=15)


# flip left right
ax = fig.add_subplot(1, 5, 5)
img_flip = tf.image.flip_left_right(img_contrast)
ax.imshow(array_to_img(img_flip))
ax.set_title("Step 4: Flip left right", size=15);
# Out:
# Metal device set to: Apple M1 Pro
# 2022-07-07 15:47:24.321381: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-07-07 15:47:24.321494: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# Next, we will define and run the **preprocess_data_part2()** function to create:
#
# * train/validation/test sets with split (0.6,0.2,0.2)
#
# * image transformation and augmentation, as follows:
#
# <u>Applied on training, validation and test sets</u>:
#   - resize to IMAGE_SIZE =(224,224) using tf.image.resize()
#   - normalize all pixel values to the range (0,1)
#
# <u>Applied on training set only</u> (note that this step will create additional/augmented copies of the training data):
#   - adjust brightness by adding DELTA=0.3 to the pixel values using tf.image.adjust_brighness()
#   - adjust contrast to CONTRAST_FACTOR=3 using tf.image.adjust_contrast()
#   - flip left right using tf.image.flip_left_right()

# %% [markdown]
# The quantity and diversity of data gathered have a significant impact on the results of a CNN model. One can apply augmentations to artificially inflate the training dataset by warping the original data such that their label does not change. These augmentations can significantly improve learning results without collecting new data.

# %%
IMAGE_SIZE = (224, 224)
CONTRAST_FACTOR = 3
DELTA = 0.3


def preprocess_data_part2(images, y, split=(0.6, 0.2, 0.2)):
    """ Split data into train, validation and test sets; apply transformaions and augmentations
    
    Params:
    -------
    images  (np.ndarray): Images of shape (N, 224, 224, 3)
    y (np.ndarray): Labels of shape (N,)   
    split (tuple): 3 values summing to 1 defining split of train, validation and test sets
    
    Returns:
    --------
    X_train (np.ndarray): Train images of shape (N_train, 224, 224, 3)
    y_train (np.ndarray): Train labels of shape (N_train,)
    X_val (np.ndarray): Val images of shape (N_val, 224, 224, 3)
    y_val (np.ndarray): Val labels of shape (N_val,)
    X_test (np.ndarray): Test images of shape (N_test, 224, 224, 3)
    y_test (np.ndarray): Test labels of shape (N_test,)
    
    """

    ### create train/validation/test sets ###
    #########################################
    # NOTE: Each time you run this cell, you'll re-shuffle the data. The ordering will be the same due to the random seed generator
    tf.random.set_seed(1234)
    np.random.seed(1234)
    shuffle = np.random.permutation(np.arange(images.shape[0]))
    images, y = images[shuffle], y[shuffle]

    splits = np.multiply(len(images_mini), split).astype(int)
    X_train, X_val, X_test = np.split(images_mini, [splits[0], splits[0] + splits[1]])
    y_train, y_val, y_test = np.split(y_mini, [splits[0], splits[0] + splits[1]])

    ### image transformation on training, validation, and test data ###
    ###################################################################
    # image resize
    X_train = tf.image.resize(X_train, size=IMAGE_SIZE)
    X_val = tf.image.resize(X_val, size=IMAGE_SIZE)
    X_test = tf.image.resize(X_test, size=IMAGE_SIZE)

    # rescale image to [0,1], i.e., greyscale
    X_train = X_train / 255.0
    X_val = X_val / 255.0
    X_test = X_test / 255.0

    ### image augmentation on training data ###
    ###########################################
    # adjust brightness
    X_train_augm = tf.image.adjust_brightness(X_train, delta=DELTA)

    # adjust contrast
    X_train_augm = tf.image.adjust_contrast(
        X_train_augm, contrast_factor=CONTRAST_FACTOR
    )

    # random flip
    X_train_augm = tf.image.random_flip_left_right(X_train_augm)

    # concatenate original X_train and augmented X_train data
    X_train = tf.concat([X_train, X_train_augm], axis=0)

    # concatenate y_train (note the label is preserved)
    y_train_augm = y_train
    y_train = tf.concat([y_train, y_train_augm], axis=0)

    # shuffle X_train and y_train, i.e., shuffle two tensors in the same order
    shuffle = tf.random.shuffle(tf.range(tf.shape(X_train)[0], dtype=tf.int32))
    X_train = tf.gather(X_train, shuffle)
    y_train = tf.gather(
        y_train, shuffle
    ).numpy()  # also transforms y_train to numpy array

    return X_train, y_train, X_val, y_val, X_test, y_test

# %% [markdown]
# Let's sanity check our implementation of the preprocess_data_part2() function by printing the shape of (X,y) from train, validation and test sets.

# %%
X_train, y_train, X_val, y_val, X_test, y_test = preprocess_data_part2(
    images_mini, y_mini, split=(0.6, 0.2, 0.2)
)

print(f"X_train shape {X_train.shape}")
print(f"y_train shape {y_train.shape}")
print(f"X_val shape {X_val.shape}")
print(f"y_val shape {y_val.shape}")
print(f"X_test shape {X_test.shape}")
print(f"y_test shape {y_test.shape}")
# Out:
# X_train shape (190, 224, 224, 3)
# y_train shape (190,)
# X_val shape (31, 224, 224, 3)
# y_val shape (31,)
# X_test shape (33, 224, 224, 3)
# y_test shape (33,)

# %% [markdown]
# Let's also print out the first 8 train and validation examples with the label of each example as the title.

# %%
# print training data
print("Print training data examples:")
nrows, ncols = 1, 4  # print first 4 images
f, axs = plt.subplots(nrows, ncols, figsize=(14, 12))
for i in range(ncols):
    axs[i].imshow(array_to_img(X_train[i]))
    axs[i].set(title=y_train[i])
# Out:
# Print training data examples:

# %%
# print test data
print("Print validation data examples:")
nrows, ncols = 1, 4  # print first 4 images
f, axs = plt.subplots(nrows, ncols, figsize=(14, 12))
for i in range(ncols):
    axs[i].imshow(array_to_img(X_val[i]))
    axs[i].set(title=y_val[i])
# Out:
# Print validation data examples:

# %% [markdown]
# ---
# ### Exercise 3 (8 points)
#
# We've split the data into train, validation, and test sets. Explain the purpose of each of these.

# %% [markdown]
# *Written answer*:
#
# The `train` set is used to train the model.
# The `validation` set is used to evaluate how the model performs on unseen data so that we can optimize hyperparameters.
# The `test` is used to evaluate our final model on unseen data that was not used to train the model or to develop hyperparameters.

# %% [markdown]
# ___

# %% [markdown]
# ## Model

# %% [markdown]
# Our objective is to build and train a CNN model to refer patients to doctors based on the severity of DR seen in these images. We are interested in exploring binary classification of 'no refer' and 'refer'.
#
# <u>The architecture of our CNN model is as follows</u>:
#
# 1. the model receives input images of size 224 x 224 x 3 (the images have three color channels)
# 2. the input data goes through two convolutional layers that have kernels of size 5 x 5
# 3. the first convolution has 32 output feature maps, and the second one has 64
# 4. each convolution layer is followed by a max-pooling layer (this will reduce the size of the feature maps)
# 5. the last two layers of the model are fully connected with a droput layer in between
#
# For each convolution we use strides=(1,1) to preserve the dimension of the inputs in the resulting feature maps. For the pooling layers, we set strides=(2,2) to subsample the image and shrink the size of the output feature maps. For the dropout layer, we set the probability of dropping input units during training to 0.5.
#
#
# We will implement this architecture using TensorFlow Keras API.

# %% [markdown]
# ``Build model``

# %%
model = tf.keras.Sequential()

# add first convolution layer to the model
model.add(
    tf.keras.layers.Conv2D(
        filters=32,
        kernel_size=(5, 5),
        strides=(1, 1),
        padding="same",
        data_format="channels_last",
        name="conv_1",
        activation="relu",
    )
)


# add a max pooling layer with pool size (2,2) and strides of 2
# (this will reduce the spatial dimensions by half)
model.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2), name="pool_1"))


# add second convolutional layer
model.add(
    tf.keras.layers.Conv2D(
        filters=64,
        kernel_size=(5, 5),
        strides=(1, 1),
        padding="same",
        name="conv_2",
        activation="relu",
    )
)

# add second max pooling layer with pool size (2,2) and strides of 2
# (this will further reduce the spatial dimensions by half)
model.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2), name="pool_2"))


# add a fully connected layer (need to flatten the output of the previous layers first)
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(units=1024, name="fc_1", activation="relu"))

# add dropout layer
model.add(tf.keras.layers.Dropout(rate=0.5))

# add the last fully connected layer
# this last layer sets the activation function to "None" in order to output the logits
# note that passing activation = "sigmoid" will return class memembership probabilities but
# in TensorFlow logits are prefered for numerical stability
# set units=1 to get a single output unit (remember it's a binary classification problem)
model.add(tf.keras.layers.Dense(units=1, name="fc_2", activation=None))


# build model and print summary
tf.random.set_seed(1)
model.build(input_shape=(None, 224, 224, 3))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv_1 (Conv2D)             (None, 224, 224, 32)      2432
#
#  pool_1 (MaxPooling2D)       (None, 112, 112, 32)      0
#
#  conv_2 (Conv2D)             (None, 112, 112, 64)      51264
#
#  pool_2 (MaxPooling2D)       (None, 56, 56, 64)        0
#
#  flatten (Flatten)           (None, 200704)            0
#
#  fc_1 (Dense)                (None, 1024)              205521920
#
#  dropout (Dropout)           (None, 1024)              0
#
#  fc_2 (Dense)                (None, 1)                 1025
#
# =================================================================
# Total params: 205,576,641
# Trainable params: 205,576,641
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ``Compile model``

# %% [markdown]
# The next step is to compile the model. We have to decide on the type of optimizer, loss function, and metrics to compute.
#
# We will use the Adam optimizer for this assignment, the most popular gradient-based optimization algorithm. There are a few other choices, and you can read more [here](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers). The loss (cost) function suitable for our binary classification model is [binary_crossentropy](https://www.tensorflow.org/api_docs/python/tf/keras/losses). We will compute model accuracy on the training, validation and test datasets.

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.BinaryCrossentropy(
        from_logits=True
    ),  # set from_ligits=True because our last layer does not apply sigmoid
    metrics=["accuracy"],
)

# %% [markdown]
# ``Fit model``

# %% [markdown]
# Finally, we will fit the model with 10 epochs on the train set and validate on the validation set. The performance depends on the current starter hyperparameters such as learning rate and choice of optimizer.

# %%
# set random seed to get reproductible results
# neural network algorithms are stochastic (e.g., due to random weight initialization); setting a random seed helps to get more stable results after each run
# however, best way to deal with randomness is to repeat your experiment many times (30+) and use statistics to summarize the performance of the model
tf.random.set_seed(1234)
np.random.seed(1234)
history = model.fit(X_train, y_train, epochs=10, validation_data=(X_val, y_val))
# Out:
# Epoch 1/10
# 2022-07-07 15:47:25.339848: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-07-07 15:47:25.479707: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 6/6 [==============================] - 2s 286ms/step - loss: 15.7248 - accuracy: 0.5316 - val_loss: 0.7187 - val_accuracy: 0.8065
# Epoch 2/10
# 2022-07-07 15:47:27.184677: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 6/6 [==============================] - 2s 262ms/step - loss: 0.4937 - accuracy: 0.8053 - val_loss: 0.4053 - val_accuracy: 0.8065
# Epoch 3/10
# 6/6 [==============================] - 2s 265ms/step - loss: 0.3936 - accuracy: 0.8211 - val_loss: 0.4212 - val_accuracy: 0.8387
# Epoch 4/10
# 6/6 [==============================] - 2s 261ms/step - loss: 0.3039 - accuracy: 0.8053 - val_loss: 0.4970 - val_accuracy: 0.7742
# Epoch 5/10
# 6/6 [==============================] - 2s 266ms/step - loss: 0.2426 - accuracy: 0.8842 - val_loss: 0.5796 - val_accuracy: 0.8065
# Epoch 6/10
# 6/6 [==============================] - 2s 264ms/step - loss: 0.1884 - accuracy: 0.8947 - val_loss: 0.5591 - val_accuracy: 0.8065
# Epoch 7/10
# 6/6 [==============================] - 2s 262ms/step - loss: 0.1737 - accuracy: 0.9263 - val_loss: 0.5865 - val_accuracy: 0.8065
# Epoch 8/10
# 6/6 [==============================] - 2s 261ms/step - loss: 0.2407 - accuracy: 0.8579 - val_loss: 0.5897 - val_accuracy: 0.8065
# Epoch 9/10
# 6/6 [==============================] - 2s 261ms/step - loss: 0.3496 - accuracy: 0.8632 - val_loss: 0.5336 - val_accuracy: 0.7742
# Epoch 10/10
# 6/6 [==============================] - 2s 261ms/step - loss: 0.2504 - accuracy: 0.8842 - val_loss: 0.4829 - val_accuracy: 0.7742

# %% [markdown]
# Next let's plot loss and accuracy for training and validation sets

# %%
hist = history.history
x_arr = np.arange(len(hist["loss"])) + 1

fig = plt.figure(figsize=(12, 4))
ax = fig.add_subplot(1, 2, 1)
ax.plot(x_arr, hist["loss"], "-o", label="Train loss")
ax.plot(x_arr, hist["val_loss"], "--<", label="Validation loss")
ax.legend(fontsize=15)
ax.set_xlabel("Epoch", size=15)
ax.set_ylabel("Loss", size=15)

ax = fig.add_subplot(1, 2, 2)
ax.plot(x_arr, hist["accuracy"], "-o", label="Train acc.")
ax.plot(x_arr, hist["val_accuracy"], "--<", label="Validation acc.")
ax.legend(fontsize=15)
ax.set_xlabel("Epoch", size=15)
ax.set_ylabel("Accuracy", size=15)
plt.show()

# %% [markdown]
# ## Show what the CNN model is learning after each layer

# %% [markdown]
# We will pick one example from our training data to visualize our CNN model's learning after each layer. Below we print the original image.

# %%
img_tensor = np.expand_dims(X_train[2], axis=0)

# Print image tensor shape
print("Shape of image:", img_tensor.shape)

# Print image
plt.imshow(img_tensor[0])
plt.title("label:" + str(y_train[1]))
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Shape of image: (1, 224, 224, 3)

# %% [markdown]
# Next we print what the model learns after each layer-channel. It's important to pay attention to the shape of the output image to understand what each layer does to the original input.

# %%
# outputs of the first 4 layers, which include conv2D and max pooling layers
layer_outputs = [layer.output for layer in model.layers[:4]]
activation_model = models.Model(inputs=model.input, outputs=layer_outputs)
activations = activation_model.predict(img_tensor)

# grab layer names
layer_names = []
for layer in model.layers[:4]:
    layer_names.append(layer.name)

# getting activations of each layer
for idx, layer in enumerate(activations):
    if idx in (0, 1, 2, 3):
        print("----------------")
        print("Getting activations of layer", idx + 1, ":", layer_names[idx])
        activation = layer

        # shape of layer activation
        print("Images size is", activation.shape[1], "x", activation.shape[2])
        print("Number of channels is", activation.shape[3])

        # print channels
        print("Printing channels:")

        # define nrows and ncols depending on number of channels
        if idx in (0, 1):
            nrows, ncols = 4, 8
        if idx in (2, 3):
            nrows, ncols = 8, 8

        # plots
        channel = 0
        if idx in (0, 1):
            f, axs = plt.subplots(nrows, ncols, figsize=(14, 12))
        if idx in (2, 3):
            f, axs = plt.subplots(nrows, ncols, figsize=(14, 20))

        for i in range(nrows):
            for j in range(ncols):
                if i == 0 and j == 0:
                    channel = 0
                else:
                    channel += 1

                axs[i, j].matshow(activation[0, :, :, channel], cmap="viridis")
                axs[i, j].set(title=str(channel))
                # axs[i,j].axis('off') # pay attention to the range of x and y axis
        plt.show()
# Out:
# ----------------
# Getting activations of layer 1 : conv_1
# Images size is 224 x 224
# Number of channels is 32
# Printing channels:
# 2022-07-07 15:47:41.497134: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# ----------------
# Getting activations of layer 2 : pool_1
# Images size is 112 x 112
# Number of channels is 32
# Printing channels:
# ----------------
# Getting activations of layer 3 : conv_2
# Images size is 112 x 112
# Number of channels is 64
# Printing channels:
# ----------------
# Getting activations of layer 4 : pool_2
# Images size is 56 x 56
# Number of channels is 64
# Printing channels:

# %% [markdown]
# As you can see, initial layers are more interpretable and retain the majority of the features in the input image. As the level of the layer increases, features become less interpretable, they become more abstract and they identify features specific to the class leaving behind the general features of the image.

# %% [markdown]
# ## Evaluation

# %% [markdown]
# Evaluation is one of the most important parts of machine learning as it helps us determine how good our trained model is in predicting unseen data.
#
# Notice that (`X_test`, and `y_test`) were not used in the training part. It would be very bad practice to evaluate the model on the test set, and then return and update the model based on those results (then the test set is acting like just another validation set).

# %% [markdown]
# We will now use our test data to evaluate the performance (accuracy) of our CNN model on unseen data. Note that accuracy is the default metric if one compiles the model with the accuracy metric.

# %%
test_results = model.evaluate(X_test, y_test)
print("\nTest Acc. {:.2f}%".format(test_results[1] * 100))
# Out:
# 2/2 [==============================] - 0s 35ms/step - loss: 0.4944 - accuracy: 0.7576
#
# Test Acc. 75.76%

# %% [markdown]
# `get predictions results in the form of class-membership probabilities`

# %% [markdown]
# In the following figure, you can see all the images in the test data along with their ground truth (GT) labels and the predicted probabiliy that they belong to class 1, 'Refer'

# %%
# transform logits to probabilities
pred_logits = model.predict(X_test)
probas = tf.sigmoid(pred_logits)
probas = probas.numpy().flatten() * 100
# Out:
# 2022-07-07 15:47:48.577954: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.

# %%
# plot test data and associated predicred
fig = plt.figure(figsize=(20, 20))

for j, example in enumerate(X_test):
    ax = fig.add_subplot(9, 4, j + 1)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.imshow(array_to_img(example))
    if y_test[j] == 0:
        label = "no refer"
    else:
        label = "refer"

    ax.text(
        0.5,
        -0.15,
        "GT: {:s}\nPr(refer)={:.0f}%".format(label, probas[j]),
        size=16,
        color="grey",
        horizontalalignment="center",
        verticalalignment="center",
        transform=ax.transAxes,
    )

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ### Exercise 4 (8 points)

# %% [markdown]
# In this exercise, your task is to experiment with different hyperparameter values to see how sensitive the accuracy of our CNN model is.  In the table below, you will fill in `training and validation accuracy` results corresponding to the last epoch of the model fit.
#
# You will change one hyperparameter value at a time, as follows:
#
# * kernel size = 3 x 3
# * strides = 2 x 2
# * pool size = 3 x 3
# * learning rate = 0.01
# * optimizer = 'SGD'
# * image augmentation applied on the training data: (brightness (delta) = 0.1, contrast = 2, flip = no)
#
# Finally, comment on the CNN model specification that you are most satisfied with based on the accuracy achieved on the training and validation sets. For this specification, what is the accuracy of the test dataset?

# %% [markdown]
# *Written answer*:
#
# | Trining accuracy | Validation accuracy |  kernel size |  strides | pool size  |  learning rate | optimizer  | brightness (delta) |  contrast factor | flip_on_train  |
# |:-:                |:-:                  |:-:           |:-:       |:-:         |:-:             |:-:         |:-:                 |:-:               |:-:             |
# | 0.94              | 0.81                | 5,5          | 1,1      | 2,2        | 0.001          | Adam       | 0.3                | 3                | yes            |
# | ...               | ...                 | <font color="red">3,3</font>     | 1,1      | 2,2        | 0.001          | Adam       | 0.3                | 3                | yes            |
# | ...               | ...                 | 5,5          | <font color="red">2,2</font>  | 2,2        | 0.001          | Adam       | 0.3                | 3                | yes            |
# | ...               | ...                 | 5,5          | 1,1      | <font color="red">3,3</font>   | 0.001          | Adam       | 0.3                | 3                | yes            |
# | ...               | ...                 | 5,5          | 1,1      | 2,2        | <font color="red">0.01</font>       | Adam       | 0.3                | 3                | yes            |
# | ...               | ...                 | 5,5          | 1,1      | 2,2        | 0.001          |<font color="red">SGD</font>     | 0.3                | 3                | yes            |
# | ...               | ...                 | 5,5          | 1,1      | 2,2        | 0.001          | Adam       | <font color="red">0.1</font>            | 3                | yes            |
# | ...               | ...                 | 5,5          | 1,1      | 2,2        | 0.001          | Adam       | 0.3                | <font color="red">2</font>            | yes            |
# | ...               | ...                 | 5,5          | 1,1      | 2,2        | 0.001          | Adam       | 0.3                | 3                | <font color="red">no</font>         |

# %%
def exercise_4_preprocess(
    images,
    y,
    brightness=0.3,
    contrast_factor=3,
    flip_on_train="yes",
    split=(0.6, 0.2, 0.2),
    image_size=(224, 224),
):

    """ Split data into train, validation and test sets; apply transformations and augmentations
    
    Params:
    -------
    images  (np.ndarray): Images of shape (N, 224, 224, 3)
    y (np.ndarray): Labels of shape (N,)
    brightness (numeric): brightness adjustment for augmented training data
    contrast_factor (numeric: contrast adjustment for augmented training data
    flip_on_train (string): if 'yes' augmented images will be flipped left to right
    split (tuple): 3 values summing to 1 defining split of train, validation and test sets
    image_size (tuple): dimensions for image resizing
    
    Returns:
    --------
    X_train (np.ndarray): Train images of shape (N_train, image_size)
    y_train (np.ndarray): Train labels of shape (N_train,)
    X_val (np.ndarray): Val images of shape (N_val, image_size, 3)
    y_val (np.ndarray): Val labels of shape (N_val,)
    X_test (np.ndarray): Test images of shape (N_test, image_size, 3)
    y_test (np.ndarray): Test labels of shape (N_test,)
    
    """

    ### create train/validation/test sets ###
    #########################################
    # NOTE: Each time you run this cell, you'll re-shuffle the data. The ordering will be the same due to the random seed generator
    tf.random.set_seed(1234)
    np.random.seed(1234)
    shuffle = np.random.permutation(np.arange(images.shape[0]))
    images, y = images[shuffle], y[shuffle]

    splits = np.multiply(len(images_mini), split).astype(int)
    X_train, X_val, X_test = np.split(images_mini, [splits[0], splits[0] + splits[1]])
    y_train, y_val, y_test = np.split(y_mini, [splits[0], splits[0] + splits[1]])

    ### image transformation on training, validation, and test data ###
    ###################################################################
    # image resize
    X_train = tf.image.resize(X_train, size=image_size)
    X_val = tf.image.resize(X_val, size=image_size)
    X_test = tf.image.resize(X_test, size=image_size)

    # rescale image to [0,1], i.e., greyscale
    X_train = X_train / 255.0
    X_val = X_val / 255.0
    X_test = X_test / 255.0

    ### image augmentation on training data ###
    ###########################################
    # adjust brightness
    X_train_augm = tf.image.adjust_brightness(X_train, delta=brightness)

    # adjust contrast
    X_train_augm = tf.image.adjust_contrast(
        X_train_augm, contrast_factor=contrast_factor
    )

    # flip
    if flip_on_train == "yes":
        X_train_augm = tf.image.flip_left_right(X_train_augm)
    elif flip_on_train == "random":
        X_train_augm = tf.image.random_flip_left_right(X_train_augm)

    # concatenate original X_train and augmented X_train data
    X_train = tf.concat([X_train, X_train_augm], axis=0)

    # concatenate y_train (note the label is preserved)
    y_train_augm = y_train
    y_train = tf.concat([y_train, y_train_augm], axis=0)

    # shuffle X_train and y_train, i.e., shuffle two tensors in the same order
    shuffle = tf.random.shuffle(tf.range(tf.shape(X_train)[0], dtype=tf.int32))
    X_train = tf.gather(X_train, shuffle)
    y_train = tf.gather(
        y_train, shuffle
    ).numpy()  # also transforms y_train to numpy array

    return X_train, y_train, X_val, y_val, X_test, y_test

# %%
def exercise_4_build_compile_model(
    kernel_size=(5, 5),
    strides=(1, 1),
    pool_size=(2, 2),
    optimizer="Adam",
    learning_rate=0.001,
):

    """ Buld and compile model.
    
    Params:
    -------
    kernel_size (tuple): kernel size dimensions
    strides (tuple): stride size for convolution layers
    pool_size (tuple): pool size for pooling layers
    optimizer (string): name of model optimizer
    learning_rate (number): optimizer learning rate
    
    Returns:
    --------
    model (keras model)
    
    """

    # Clear session and remove randomness.
    tf.keras.backend.clear_session()

    model = tf.keras.Sequential()

    # add first convolution layer to the model
    model.add(
        tf.keras.layers.Conv2D(
            filters=32,
            kernel_size=kernel_size,
            strides=strides,
            padding="same",
            data_format="channels_last",
            name="conv_1",
            activation="relu",
        )
    )

    # add a max pooling layer with pool size pool_size and strides derived from
    # pool size (this will reduce the spatial dimensions)
    model.add(tf.keras.layers.MaxPool2D(pool_size=pool_size, name="pool_1"))

    # add second convolutional layer
    model.add(
        tf.keras.layers.Conv2D(
            filters=64,
            kernel_size=kernel_size,
            strides=strides,
            padding="same",
            name="conv_2",
            activation="relu",
        )
    )

    # add second max pooling layer with pool size pool_size and strides derived from
    # pool size (this will further reduce the spatial dimensions)
    model.add(tf.keras.layers.MaxPool2D(pool_size=pool_size, name="pool_2"))

    # add a fully connected layer (need to flatten the output of the previous layers first)
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(units=1024, name="fc_1", activation="relu"))

    # add dropout layer
    model.add(tf.keras.layers.Dropout(rate=0.5))

    # add the last fully connected layer
    # this last layer sets the activation function to "None" in order to output the logits
    # note that passing activation = "sigmoid" will return class memembership probabilities but
    # in TensorFlow logits are prefered for numerical stability
    # set units=1 to get a single output unit (remember it's a binary classification problem)
    model.add(tf.keras.layers.Dense(units=1, name="fc_2", activation=None))

    # build model
    tf.random.set_seed(1)
    model.build(input_shape=(None, 224, 224, 3))

    if optimizer == "Adam":
        optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    elif optimizer == "SGD":
        optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate)
    else:
        warnings.warn("Invalid optimizer")

    model.compile(
        optimizer=optimizer,
        loss=tf.keras.losses.BinaryCrossentropy(
            from_logits=True
        ),  # set from_ligits=True because our last layer does not apply sigmoid
        metrics=["accuracy"],
    )

    return model

# %%
def get_final_accuracy(history):
    if not isinstance(history, pd.DataFrame):
        history = pd.DataFrame(history.history)
    return history["accuracy"].values[-1], history["val_accuracy"].values[-1]

# %% [markdown]
# ---

# %%
DEFAULT_KERNEL_SIZE = (5, 5)
DEFAULT_STRIDES = (1, 1)
DEFAULT_POOL_SIZE = (2, 2)
DEFAULT_LEARNING_RATE = 0.001
DEFAULT_OPTIMIZER = "Adam"
DEFAULT_BRIGHTNESS = 0.3
DEFAULT_CONTRAST_FACTOR = 3
DEFAULT_FLIP_ON_TRAIN = "random"


def experiment(
    kernel_size=DEFAULT_KERNEL_SIZE,
    strides=DEFAULT_STRIDES,
    pool_size=DEFAULT_POOL_SIZE,
    learning_rate=DEFAULT_LEARNING_RATE,
    optimizer=DEFAULT_OPTIMIZER,
    brightness=DEFAULT_BRIGHTNESS,
    contrast_factor=DEFAULT_CONTRAST_FACTOR,
    flip_on_train=DEFAULT_FLIP_ON_TRAIN,
    verbose=0,
):

    processor = platform.processor()
    gpu = tf.config.list_logical_devices("GPU")

    id = locals()
    del id["verbose"]

    id_string = " ".join([str(k) + ":" + str(v) for k, v in id.items()])

    print(id_string)
    tf.random.set_seed(1234)
    np.random.seed(1234)

    X_train, y_train, X_val, y_val, X_test, y_test = exercise_4_preprocess(
        images_mini,
        y_mini,
        brightness=brightness,
        contrast_factor=contrast_factor,
        flip_on_train=flip_on_train,
    )
    model = exercise_4_build_compile_model(
        kernel_size=kernel_size,
        strides=strides,
        pool_size=pool_size,
        learning_rate=learning_rate,
        optimizer=optimizer,
    )

    history = model.fit(
        X_train, y_train, epochs=10, validation_data=(X_val, y_val), verbose=verbose
    )

    final_train_accuracy, final_validation_accuracy = get_final_accuracy(history)
    print(
        f"Train Accuracy {final_train_accuracy:.4f} Validation Accuracy {final_validation_accuracy:.4f}"
    )
    return (id, final_train_accuracy, final_validation_accuracy)

# %%
def panel(tests, filename=None):
    results = [(experiment(**test)) for test in tests]

    accuracy = [(round(result[1], 4), round(result[2], 4)) for result in results]
    ids = [result[0] for result in results]

    acc_df = pd.DataFrame(accuracy, columns=["train_accuracy", "validation_accuracy"])
    id_df = pd.DataFrame(ids)
    result_df = acc_df.join(id_df)
    result_df["batch"] = int(time())

    if filename is not None:
        if os.path.exists(filename):
            mode, header = "a", False
        else:
            mode, header = "w", True
            result_df.index.name = "panel_index"

        with open(filename, mode) as f:
            result_df.to_csv(f, header=header)

    return result_df

# %%
tests = [
    {"kernel_size": (5, 5)},
    {"kernel_size": (3, 3)},
    {"strides": (2, 2)},
    {"pool_size": (3, 3)},
    {"learning_rate": 0.01},
    {"optimizer": "SGD"},
    {"brightness": 0.1},
    {"contrast_factor": 2},
    {"flip_on_train": "yes"},
    {"flip_on_train": "no"},
]

# %%
panel(tests, "homework_10_exercise_4_results.csv")
# Out:
# kernel_size:(5, 5) strides:(1, 1) pool_size:(2, 2) learning_rate:0.001 optimizer:Adam brightness:0.3 contrast_factor:3 flip_on_train:random processor:arm gpu:[LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2022-07-07 15:47:50.043356: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-07-07 15:47:51.758560: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Train Accuracy 0.8842 Validation Accuracy 0.7742
# kernel_size:(3, 3) strides:(1, 1) pool_size:(2, 2) learning_rate:0.001 optimizer:Adam brightness:0.3 contrast_factor:3 flip_on_train:random processor:arm gpu:[LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2022-07-07 15:48:06.137983: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-07-07 15:48:07.609829: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Train Accuracy 0.9684 Validation Accuracy 0.7742
# kernel_size:(5, 5) strides:(2, 2) pool_size:(2, 2) learning_rate:0.001 optimizer:Adam brightness:0.3 contrast_factor:3 flip_on_train:random processor:arm gpu:[LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2022-07-07 15:48:20.236452: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-07-07 15:48:20.589600: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Train Accuracy 0.9000 Validation Accuracy 0.7742
# kernel_size:(5, 5) strides:(1, 1) pool_size:(3, 3) learning_rate:0.001 optimizer:Adam brightness:0.3 contrast_factor:3 flip_on_train:random processor:arm gpu:[LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2022-07-07 15:48:22.570140: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-07-07 15:48:23.366139: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Train Accuracy 0.9000 Validation Accuracy 0.8065
# kernel_size:(5, 5) strides:(1, 1) pool_size:(2, 2) learning_rate:0.01 optimizer:Adam brightness:0.3 contrast_factor:3 flip_on_train:random processor:arm gpu:[LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2022-07-07 15:48:29.094038: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-07-07 15:48:31.049810: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Train Accuracy 0.8789 Validation Accuracy 0.8387
# kernel_size:(5, 5) strides:(1, 1) pool_size:(2, 2) learning_rate:0.001 optimizer:SGD brightness:0.3 contrast_factor:3 flip_on_train:random processor:arm gpu:[LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2022-07-07 15:48:48.618662: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-07-07 15:48:50.348835: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Train Accuracy 0.7053 Validation Accuracy 0.7097
# kernel_size:(5, 5) strides:(1, 1) pool_size:(2, 2) learning_rate:0.001 optimizer:Adam brightness:0.1 contrast_factor:3 flip_on_train:random processor:arm gpu:[LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2022-07-07 15:49:06.248511: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-07-07 15:49:09.554630: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Train Accuracy 0.9211 Validation Accuracy 0.7742
# kernel_size:(5, 5) strides:(1, 1) pool_size:(2, 2) learning_rate:0.001 optimizer:Adam brightness:0.3 contrast_factor:2 flip_on_train:random processor:arm gpu:[LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2022-07-07 15:49:27.692647: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-07-07 15:49:31.136347: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Train Accuracy 0.8421 Validation Accuracy 0.8065
# kernel_size:(5, 5) strides:(1, 1) pool_size:(2, 2) learning_rate:0.001 optimizer:Adam brightness:0.3 contrast_factor:3 flip_on_train:yes processor:arm gpu:[LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2022-07-07 15:49:48.891705: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-07-07 15:49:51.386368: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Train Accuracy 0.8895 Validation Accuracy 0.8065
# kernel_size:(5, 5) strides:(1, 1) pool_size:(2, 2) learning_rate:0.001 optimizer:Adam brightness:0.3 contrast_factor:3 flip_on_train:no processor:arm gpu:[LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2022-07-07 15:50:12.043688: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-07-07 15:50:13.959675: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Train Accuracy 0.9263 Validation Accuracy 0.7419
#    train_accuracy  validation_accuracy kernel_size strides pool_size  \
# 0          0.8842               0.7742      (5, 5)  (1, 1)    (2, 2)
# 1          0.9684               0.7742      (3, 3)  (1, 1)    (2, 2)
# 2          0.9000               0.7742      (5, 5)  (2, 2)    (2, 2)
# 3          0.9000               0.8065      (5, 5)  (1, 1)    (3, 3)
# 4          0.8789               0.8387      (5, 5)  (1, 1)    (2, 2)
# 5          0.7053               0.7097      (5, 5)  (1, 1)    (2, 2)
# 6          0.9211               0.7742      (5, 5)  (1, 1)    (2, 2)
# 7          0.8421               0.8065      (5, 5)  (1, 1)    (2, 2)
# 8          0.8895               0.8065      (5, 5)  (1, 1)    (2, 2)
# 9          0.9263               0.7419      (5, 5)  (1, 1)    (2, 2)
#
#    learning_rate optimizer  brightness  contrast_factor flip_on_train  \
# 0          0.001      Adam         0.3                3        random
# 1          0.001      Adam         0.3                3        random
# 2          0.001      Adam         0.3                3        random
# 3          0.001      Adam         0.3                3        random
# 4          0.010      Adam         0.3                3        random
# 5          0.001       SGD         0.3                3        random
# 6          0.001      Adam         0.1                3        random
# 7          0.001      Adam         0.3                2        random
# 8          0.001      Adam         0.3                3           yes
# 9          0.001      Adam         0.3                3            no
#
#   processor                     gpu       batch
# 0       arm  [(/device:GPU:0, GPU)]  1657227028
# 1       arm  [(/device:GPU:0, GPU)]  1657227028
# 2       arm  [(/device:GPU:0, GPU)]  1657227028
# 3       arm  [(/device:GPU:0, GPU)]  1657227028
# 4       arm  [(/device:GPU:0, GPU)]  1657227028
# 5       arm  [(/device:GPU:0, GPU)]  1657227028
# 6       arm  [(/device:GPU:0, GPU)]  1657227028
# 7       arm  [(/device:GPU:0, GPU)]  1657227028
# 8       arm  [(/device:GPU:0, GPU)]  1657227028
# 9       arm  [(/device:GPU:0, GPU)]  1657227028

# %%
if tf.config.list_logical_devices("GPU"):
    panel(tests, "homework_10_exercise_4_results.csv")
# Out:
# kernel_size:(5, 5) strides:(1, 1) pool_size:(2, 2) learning_rate:0.001 optimizer:Adam brightness:0.3 contrast_factor:3 flip_on_train:random processor:arm gpu:[LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2022-07-07 15:50:28.939200: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-07-07 15:50:30.580565: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Train Accuracy 0.8789 Validation Accuracy 0.7742
# kernel_size:(3, 3) strides:(1, 1) pool_size:(2, 2) learning_rate:0.001 optimizer:Adam brightness:0.3 contrast_factor:3 flip_on_train:random processor:arm gpu:[LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2022-07-07 15:50:45.351740: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-07-07 15:50:47.005311: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Train Accuracy 0.9421 Validation Accuracy 0.8387
# kernel_size:(5, 5) strides:(2, 2) pool_size:(2, 2) learning_rate:0.001 optimizer:Adam brightness:0.3 contrast_factor:3 flip_on_train:random processor:arm gpu:[LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2022-07-07 15:51:01.863117: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-07-07 15:51:02.205396: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Train Accuracy 0.8947 Validation Accuracy 0.7742
# kernel_size:(5, 5) strides:(1, 1) pool_size:(3, 3) learning_rate:0.001 optimizer:Adam brightness:0.3 contrast_factor:3 flip_on_train:random processor:arm gpu:[LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2022-07-07 15:51:04.201757: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-07-07 15:51:05.118486: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Train Accuracy 0.9000 Validation Accuracy 0.8065
# kernel_size:(5, 5) strides:(1, 1) pool_size:(2, 2) learning_rate:0.01 optimizer:Adam brightness:0.3 contrast_factor:3 flip_on_train:random processor:arm gpu:[LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2022-07-07 15:51:12.670480: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-07-07 15:51:14.569030: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Train Accuracy 0.8684 Validation Accuracy 0.7419
# kernel_size:(5, 5) strides:(1, 1) pool_size:(2, 2) learning_rate:0.001 optimizer:SGD brightness:0.3 contrast_factor:3 flip_on_train:random processor:arm gpu:[LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2022-07-07 15:51:32.115826: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-07-07 15:51:33.832769: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Train Accuracy 0.7105 Validation Accuracy 0.7097
# kernel_size:(5, 5) strides:(1, 1) pool_size:(2, 2) learning_rate:0.001 optimizer:Adam brightness:0.1 contrast_factor:3 flip_on_train:random processor:arm gpu:[LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2022-07-07 15:51:49.585073: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-07-07 15:51:52.194456: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Train Accuracy 0.9421 Validation Accuracy 0.7742
# kernel_size:(5, 5) strides:(1, 1) pool_size:(2, 2) learning_rate:0.001 optimizer:Adam brightness:0.3 contrast_factor:2 flip_on_train:random processor:arm gpu:[LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2022-07-07 15:52:10.093686: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-07-07 15:52:13.382743: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Train Accuracy 0.8632 Validation Accuracy 0.7742
# kernel_size:(5, 5) strides:(1, 1) pool_size:(2, 2) learning_rate:0.001 optimizer:Adam brightness:0.3 contrast_factor:3 flip_on_train:yes processor:arm gpu:[LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2022-07-07 15:52:31.494884: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-07-07 15:52:33.940001: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Train Accuracy 0.9105 Validation Accuracy 0.7097
# kernel_size:(5, 5) strides:(1, 1) pool_size:(2, 2) learning_rate:0.001 optimizer:Adam brightness:0.3 contrast_factor:3 flip_on_train:no processor:arm gpu:[LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2022-07-07 15:52:51.866512: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-07-07 15:52:54.378763: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Train Accuracy 0.8421 Validation Accuracy 0.7419

# %%
if tf.config.list_logical_devices("GPU"):
    panel(tests, "homework_10_exercise_4_results.csv")
# Out:
# kernel_size:(5, 5) strides:(1, 1) pool_size:(2, 2) learning_rate:0.001 optimizer:Adam brightness:0.3 contrast_factor:3 flip_on_train:random processor:arm gpu:[LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2022-07-07 15:53:12.528947: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-07-07 15:53:14.558496: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Train Accuracy 0.9263 Validation Accuracy 0.7742
# kernel_size:(3, 3) strides:(1, 1) pool_size:(2, 2) learning_rate:0.001 optimizer:Adam brightness:0.3 contrast_factor:3 flip_on_train:random processor:arm gpu:[LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2022-07-07 15:53:32.408479: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-07-07 15:53:34.747018: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Train Accuracy 0.9684 Validation Accuracy 0.8065
# kernel_size:(5, 5) strides:(2, 2) pool_size:(2, 2) learning_rate:0.001 optimizer:Adam brightness:0.3 contrast_factor:3 flip_on_train:random processor:arm gpu:[LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2022-07-07 15:53:50.748236: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-07-07 15:53:51.174396: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Train Accuracy 0.8842 Validation Accuracy 0.8065
# kernel_size:(5, 5) strides:(1, 1) pool_size:(3, 3) learning_rate:0.001 optimizer:Adam brightness:0.3 contrast_factor:3 flip_on_train:random processor:arm gpu:[LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2022-07-07 15:53:53.873195: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-07-07 15:53:54.811738: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Train Accuracy 0.8526 Validation Accuracy 0.8387
# kernel_size:(5, 5) strides:(1, 1) pool_size:(2, 2) learning_rate:0.01 optimizer:Adam brightness:0.3 contrast_factor:3 flip_on_train:random processor:arm gpu:[LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2022-07-07 15:54:06.333850: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-07-07 15:54:08.501273: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Train Accuracy 0.8211 Validation Accuracy 0.7742
# kernel_size:(5, 5) strides:(1, 1) pool_size:(2, 2) learning_rate:0.001 optimizer:SGD brightness:0.3 contrast_factor:3 flip_on_train:random processor:arm gpu:[LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2022-07-07 15:54:23.497908: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-07-07 15:54:24.953161: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Train Accuracy 0.7263 Validation Accuracy 0.7097
# kernel_size:(5, 5) strides:(1, 1) pool_size:(2, 2) learning_rate:0.001 optimizer:Adam brightness:0.1 contrast_factor:3 flip_on_train:random processor:arm gpu:[LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2022-07-07 15:54:37.568004: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-07-07 15:54:39.225799: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Train Accuracy 0.9421 Validation Accuracy 0.7419
# kernel_size:(5, 5) strides:(1, 1) pool_size:(2, 2) learning_rate:0.001 optimizer:Adam brightness:0.3 contrast_factor:2 flip_on_train:random processor:arm gpu:[LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2022-07-07 15:54:54.602226: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-07-07 15:54:56.496654: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Train Accuracy 0.8579 Validation Accuracy 0.7742
# kernel_size:(5, 5) strides:(1, 1) pool_size:(2, 2) learning_rate:0.001 optimizer:Adam brightness:0.3 contrast_factor:3 flip_on_train:yes processor:arm gpu:[LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2022-07-07 15:55:14.016711: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-07-07 15:55:15.930782: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Train Accuracy 0.8842 Validation Accuracy 0.7419
# kernel_size:(5, 5) strides:(1, 1) pool_size:(2, 2) learning_rate:0.001 optimizer:Adam brightness:0.3 contrast_factor:3 flip_on_train:no processor:arm gpu:[LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2022-07-07 15:55:33.379650: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-07-07 15:55:35.273254: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Train Accuracy 0.9632 Validation Accuracy 0.7742
