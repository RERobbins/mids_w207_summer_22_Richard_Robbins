# %%
from tensorflow.python.util import deprecation

from experiment import *

deprecation._PRINT_DEPRECATION_WARNINGS = False

tf.get_logger().setLevel("ERROR")

tf.config.set_visible_devices([], "GPU")

# %%
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
tf.config.list_logical_devices()
# Out:
# [LogicalDevice(name='/device:CPU:0', device_type='CPU')]

# %%
base_experiment_parameters = {
    "vocab_size": 3000,
    "sequence_length": 300,
    "hidden_layers": [3000, 1500],
    "embedding_dim": 2,
    "dropout_rate": 0.5,
}

experiment_parameters = {
    "vocab_size": 6000,
    "sequence_length": 600,
    "hidden_layers": [6000],
    "embedding_dim": 2,
    "dropout_rate": 0.3,
}

# %%
experiment(**base_experiment_parameters, verbose=1)
# Out:
# Epoch 1/5
# 2022-07-04 16:58:06.231052: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 352/352 [==============================] - 3s 9ms/step - loss: 0.6187 - accuracy: 0.6094 - val_loss: 0.3841 - val_accuracy: 0.8424
# Epoch 2/5
# 352/352 [==============================] - 3s 9ms/step - loss: 0.4360 - accuracy: 0.7692 - val_loss: 0.3243 - val_accuracy: 0.8712
# Epoch 3/5
# 352/352 [==============================] - 3s 9ms/step - loss: 0.3944 - accuracy: 0.7915 - val_loss: 0.3123 - val_accuracy: 0.8704
# Epoch 4/5
# 352/352 [==============================] - 3s 9ms/step - loss: 0.3844 - accuracy: 0.7966 - val_loss: 0.3028 - val_accuracy: 0.8764
# Epoch 5/5
# 352/352 [==============================] - 3s 9ms/step - loss: 0.3721 - accuracy: 0.8005 - val_loss: 0.3012 - val_accuracy: 0.8788
# 782/782 [==============================] - 1s 2ms/step - loss: 0.2942 - accuracy: 0.8775
# Final accuracy: train 0.8005 validation 0.8788 test 0.8775
# Final training accuracy: 0.8005
# Final validation accuracy: 0.8788
# Model parameter count: 4,518,001
# (<keras.engine.sequential.Sequential at 0x292f997f0>,
#  <keras.callbacks.History at 0x29ce19e80>,
#  0.8787999749183655,
#  0.8774799704551697)

# %%
experiment(**experiment_parameters, verbose=1)
# Out:
# Epoch 1/5
# 352/352 [==============================] - 1s 3ms/step - loss: 0.6810 - accuracy: 0.5569 - val_loss: 0.6008 - val_accuracy: 0.7448
# Epoch 2/5
# 352/352 [==============================] - 1s 3ms/step - loss: 0.4589 - accuracy: 0.7962 - val_loss: 0.3611 - val_accuracy: 0.8552
# Epoch 3/5
# 352/352 [==============================] - 1s 3ms/step - loss: 0.3456 - accuracy: 0.8502 - val_loss: 0.3179 - val_accuracy: 0.8748
# Epoch 4/5
# 352/352 [==============================] - 1s 3ms/step - loss: 0.3102 - accuracy: 0.8635 - val_loss: 0.3045 - val_accuracy: 0.8832
# Epoch 5/5
# 352/352 [==============================] - 1s 3ms/step - loss: 0.2890 - accuracy: 0.8720 - val_loss: 0.2980 - val_accuracy: 0.8880
# 782/782 [==============================] - 0s 590us/step - loss: 0.2842 - accuracy: 0.8875
# Final accuracy: train 0.8720 validation 0.8880 test 0.8875
# Final training accuracy: 0.8720
# Final validation accuracy: 0.8880
# Model parameter count: 36,001
# (<keras.engine.sequential.Sequential at 0x13650b0d0>,
#  <keras.callbacks.History at 0x2a0360c40>,
#  0.8880000114440918,
#  0.8875200152397156)

# %%
results, max_value_key = next_step(**experiment_parameters, verbose=0, test_run=False)
# Out:
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [], "embedding_dim": 1, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.6214 validation 0.7608 test 0.7477
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [6000], "embedding_dim": 1, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8270 validation 0.8812 test 0.8856
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [6000, 3000], "embedding_dim": 1, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8336 validation 0.8880 test 0.8880
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [100], "embedding_dim": 1, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7976 validation 0.8700 test 0.8728
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [100, 20], "embedding_dim": 1, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8226 validation 0.8844 test 0.8853
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [], "embedding_dim": 1, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.6214 validation 0.7608 test 0.7477
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [6000], "embedding_dim": 1, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7848 validation 0.8828 test 0.8860
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [6000, 3000], "embedding_dim": 1, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7922 validation 0.8812 test 0.8830
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [100], "embedding_dim": 1, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7603 validation 0.8692 test 0.8727
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [100, 20], "embedding_dim": 1, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7837 validation 0.8848 test 0.8850
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [], "embedding_dim": 1, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.6214 validation 0.7608 test 0.7477
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [6000], "embedding_dim": 1, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7396 validation 0.8856 test 0.8852
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [6000, 3000], "embedding_dim": 1, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7484 validation 0.8820 test 0.8829
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [100], "embedding_dim": 1, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7228 validation 0.8684 test 0.8725
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [100, 20], "embedding_dim": 1, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7397 validation 0.8816 test 0.8824
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [], "embedding_dim": 2, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7018 validation 0.7740 test 0.7674
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [6000], "embedding_dim": 2, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8966 validation 0.8892 test 0.8888
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [6000, 3000], "embedding_dim": 2, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.9060 validation 0.8836 test 0.8780
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [100], "embedding_dim": 2, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8714 validation 0.8776 test 0.8784
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [100, 20], "embedding_dim": 2, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8913 validation 0.8856 test 0.8860
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [], "embedding_dim": 2, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7018 validation 0.7740 test 0.7674
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [6000], "embedding_dim": 2, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8720 validation 0.8880 test 0.8875
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [6000, 3000], "embedding_dim": 2, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8828 validation 0.8924 test 0.8878
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [100], "embedding_dim": 2, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8509 validation 0.8760 test 0.8781
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [100, 20], "embedding_dim": 2, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8721 validation 0.8840 test 0.8848
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [], "embedding_dim": 2, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7018 validation 0.7740 test 0.7674
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [6000], "embedding_dim": 2, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8440 validation 0.8864 test 0.8834
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [6000, 3000], "embedding_dim": 2, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8501 validation 0.8924 test 0.8886
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [100], "embedding_dim": 2, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8264 validation 0.8736 test 0.8767
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [100, 20], "embedding_dim": 2, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8427 validation 0.8828 test 0.8804
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [], "embedding_dim": 3, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7457 validation 0.7904 test 0.7847
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [6000], "embedding_dim": 3, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.9156 validation 0.8912 test 0.8893
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [6000, 3000], "embedding_dim": 3, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.9253 validation 0.8756 test 0.8669
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [100], "embedding_dim": 3, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8915 validation 0.8796 test 0.8794
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [100, 20], "embedding_dim": 3, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.9128 validation 0.8892 test 0.8873
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [], "embedding_dim": 3, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7457 validation 0.7904 test 0.7847
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [6000], "embedding_dim": 3, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.9068 validation 0.8904 test 0.8884
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [6000, 3000], "embedding_dim": 3, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.9123 validation 0.8876 test 0.8809
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [100], "embedding_dim": 3, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8828 validation 0.8744 test 0.8760
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [100, 20], "embedding_dim": 3, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.9009 validation 0.8812 test 0.8802
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [], "embedding_dim": 3, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7457 validation 0.7904 test 0.7847
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [6000], "embedding_dim": 3, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8875 validation 0.8840 test 0.8842
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [6000, 3000], "embedding_dim": 3, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8944 validation 0.8800 test 0.8783
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [100], "embedding_dim": 3, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8679 validation 0.8748 test 0.8772
# {"vocab_size": 6000, "sequence_length": 600, "hidden_layers": [100, 20], "embedding_dim": 3, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8807 validation 0.8780 test 0.8774
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [], "embedding_dim": 1, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.6161 validation 0.7504 test 0.7417
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [6000], "embedding_dim": 1, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8258 validation 0.8816 test 0.8843
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [6000, 3000], "embedding_dim": 1, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8300 validation 0.8880 test 0.8859
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [100], "embedding_dim": 1, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7976 validation 0.8648 test 0.8714
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [100, 20], "embedding_dim": 1, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8182 validation 0.8836 test 0.8831
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [], "embedding_dim": 1, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.6161 validation 0.7504 test 0.7417
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [6000], "embedding_dim": 1, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7837 validation 0.8828 test 0.8855
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [6000, 3000], "embedding_dim": 1, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7885 validation 0.8832 test 0.8830
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [100], "embedding_dim": 1, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7581 validation 0.8692 test 0.8717
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [100, 20], "embedding_dim": 1, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7784 validation 0.8824 test 0.8824
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [], "embedding_dim": 1, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.6161 validation 0.7504 test 0.7417
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [6000], "embedding_dim": 1, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7416 validation 0.8840 test 0.8845
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [6000, 3000], "embedding_dim": 1, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7472 validation 0.8800 test 0.8799
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [100], "embedding_dim": 1, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7207 validation 0.8676 test 0.8715
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [100, 20], "embedding_dim": 1, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7394 validation 0.8812 test 0.8822
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [], "embedding_dim": 2, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.6991 validation 0.7708 test 0.7640
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [6000], "embedding_dim": 2, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8957 validation 0.8880 test 0.8890
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [6000, 3000], "embedding_dim": 2, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.9032 validation 0.8784 test 0.8755
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [100], "embedding_dim": 2, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8696 validation 0.8788 test 0.8774
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [100, 20], "embedding_dim": 2, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8938 validation 0.8880 test 0.8862
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [], "embedding_dim": 2, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.6991 validation 0.7708 test 0.7640
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [6000], "embedding_dim": 2, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8752 validation 0.8892 test 0.8875
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [6000, 3000], "embedding_dim": 2, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8796 validation 0.8932 test 0.8892
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [100], "embedding_dim": 2, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8499 validation 0.8760 test 0.8766
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [100, 20], "embedding_dim": 2, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8712 validation 0.8848 test 0.8836
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [], "embedding_dim": 2, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.6991 validation 0.7708 test 0.7640
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [6000], "embedding_dim": 2, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8425 validation 0.8884 test 0.8840
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [6000, 3000], "embedding_dim": 2, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8506 validation 0.8948 test 0.8878
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [100], "embedding_dim": 2, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8251 validation 0.8736 test 0.8752
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [100, 20], "embedding_dim": 2, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8426 validation 0.8852 test 0.8824
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [], "embedding_dim": 3, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7412 validation 0.7888 test 0.7831
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [6000], "embedding_dim": 3, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.9143 validation 0.8864 test 0.8895
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [6000, 3000], "embedding_dim": 3, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.9218 validation 0.8684 test 0.8613
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [100], "embedding_dim": 3, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8900 validation 0.8792 test 0.8786
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [100, 20], "embedding_dim": 3, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.9098 validation 0.8864 test 0.8845
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [], "embedding_dim": 3, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7412 validation 0.7888 test 0.7831
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [6000], "embedding_dim": 3, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.9041 validation 0.8888 test 0.8885
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [6000, 3000], "embedding_dim": 3, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.9097 validation 0.8872 test 0.8829
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [100], "embedding_dim": 3, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8809 validation 0.8732 test 0.8746
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [100, 20], "embedding_dim": 3, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8974 validation 0.8820 test 0.8827
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [], "embedding_dim": 3, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7412 validation 0.7888 test 0.7831
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [6000], "embedding_dim": 3, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8850 validation 0.8860 test 0.8845
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [6000, 3000], "embedding_dim": 3, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8924 validation 0.8848 test 0.8796
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [100], "embedding_dim": 3, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8650 validation 0.8716 test 0.8745
# {"vocab_size": 6000, "sequence_length": 660, "hidden_layers": [100, 20], "embedding_dim": 3, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8793 validation 0.8824 test 0.8833
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [], "embedding_dim": 1, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.6227 validation 0.7624 test 0.7510
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [6604], "embedding_dim": 1, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8232 validation 0.8832 test 0.8858
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [6604, 3302], "embedding_dim": 1, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8306 validation 0.8880 test 0.8878
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [100], "embedding_dim": 1, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8009 validation 0.8716 test 0.8742
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [100, 20], "embedding_dim": 1, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8220 validation 0.8812 test 0.8834
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [], "embedding_dim": 1, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.6227 validation 0.7624 test 0.7510
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [6604], "embedding_dim": 1, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7862 validation 0.8836 test 0.8862
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [6604, 3302], "embedding_dim": 1, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7944 validation 0.8892 test 0.8867
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [100], "embedding_dim": 1, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7603 validation 0.8704 test 0.8729
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [100, 20], "embedding_dim": 1, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7824 validation 0.8836 test 0.8846
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [], "embedding_dim": 1, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.6227 validation 0.7624 test 0.7510
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [6604], "embedding_dim": 1, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7417 validation 0.8820 test 0.8857
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [6604, 3302], "embedding_dim": 1, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7496 validation 0.8796 test 0.8820
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [100], "embedding_dim": 1, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7234 validation 0.8696 test 0.8730
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [100, 20], "embedding_dim": 1, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7424 validation 0.8796 test 0.8830
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [], "embedding_dim": 2, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7036 validation 0.7776 test 0.7706
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [6604], "embedding_dim": 2, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8972 validation 0.8916 test 0.8878
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [6604, 3302], "embedding_dim": 2, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.9075 validation 0.8908 test 0.8845
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [100], "embedding_dim": 2, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8732 validation 0.8796 test 0.8794
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [100, 20], "embedding_dim": 2, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8932 validation 0.8908 test 0.8865
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [], "embedding_dim": 2, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7036 validation 0.7776 test 0.7706
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [6604], "embedding_dim": 2, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8733 validation 0.8888 test 0.8863
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [6604, 3302], "embedding_dim": 2, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8849 validation 0.8920 test 0.8892
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [100], "embedding_dim": 2, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8537 validation 0.8776 test 0.8794
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [100, 20], "embedding_dim": 2, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8730 validation 0.8832 test 0.8852
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [], "embedding_dim": 2, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7036 validation 0.7776 test 0.7706
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [6604], "embedding_dim": 2, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8437 validation 0.8876 test 0.8822
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [6604, 3302], "embedding_dim": 2, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8552 validation 0.8924 test 0.8893
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [100], "embedding_dim": 2, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8263 validation 0.8756 test 0.8762
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [100, 20], "embedding_dim": 2, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8426 validation 0.8824 test 0.8806
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [], "embedding_dim": 3, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7466 validation 0.7888 test 0.7866
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [6604], "embedding_dim": 3, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.9173 validation 0.8940 test 0.8899
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [6604, 3302], "embedding_dim": 3, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.9279 validation 0.8724 test 0.8660
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [100], "embedding_dim": 3, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8929 validation 0.8816 test 0.8802
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [100, 20], "embedding_dim": 3, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.9141 validation 0.8928 test 0.8884
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [], "embedding_dim": 3, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7466 validation 0.7888 test 0.7866
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [6604], "embedding_dim": 3, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.9085 validation 0.8924 test 0.8899
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [6604, 3302], "embedding_dim": 3, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.9144 validation 0.8876 test 0.8819
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [100], "embedding_dim": 3, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8841 validation 0.8760 test 0.8761
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [100, 20], "embedding_dim": 3, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.9032 validation 0.8844 test 0.8836
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [], "embedding_dim": 3, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7466 validation 0.7888 test 0.7866
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [6604], "embedding_dim": 3, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8882 validation 0.8848 test 0.8837
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [6604, 3302], "embedding_dim": 3, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8941 validation 0.8888 test 0.8874
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [100], "embedding_dim": 3, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8685 validation 0.8752 test 0.8778
# {"vocab_size": 6604, "sequence_length": 600, "hidden_layers": [100, 20], "embedding_dim": 3, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8826 validation 0.8716 test 0.8723
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [], "embedding_dim": 1, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.6175 validation 0.7548 test 0.7444
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [6604], "embedding_dim": 1, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8245 validation 0.8848 test 0.8852
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [6604, 3302], "embedding_dim": 1, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8328 validation 0.8900 test 0.8875
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [100], "embedding_dim": 1, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7966 validation 0.8684 test 0.8726
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [100, 20], "embedding_dim": 1, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8215 validation 0.8856 test 0.8848
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [], "embedding_dim": 1, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.6175 validation 0.7548 test 0.7444
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [6604], "embedding_dim": 1, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7824 validation 0.8860 test 0.8859
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [6604, 3302], "embedding_dim": 1, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7932 validation 0.8896 test 0.8867
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [100], "embedding_dim": 1, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7600 validation 0.8704 test 0.8726
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [100, 20], "embedding_dim": 1, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7804 validation 0.8828 test 0.8827
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [], "embedding_dim": 1, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.6175 validation 0.7548 test 0.7444
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [6604], "embedding_dim": 1, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7412 validation 0.8820 test 0.8853
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [6604, 3302], "embedding_dim": 1, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7497 validation 0.8816 test 0.8814
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [100], "embedding_dim": 1, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7220 validation 0.8692 test 0.8717
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [100, 20], "embedding_dim": 1, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7394 validation 0.8812 test 0.8826
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [], "embedding_dim": 2, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7004 validation 0.7728 test 0.7671
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [6604], "embedding_dim": 2, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8981 validation 0.8920 test 0.8889
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [6604, 3302], "embedding_dim": 2, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.9054 validation 0.8828 test 0.8784
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [100], "embedding_dim": 2, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8718 validation 0.8792 test 0.8783
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [100, 20], "embedding_dim": 2, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8935 validation 0.8892 test 0.8864
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [], "embedding_dim": 2, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7004 validation 0.7728 test 0.7671
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [6604], "embedding_dim": 2, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8740 validation 0.8904 test 0.8868
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [6604, 3302], "embedding_dim": 2, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8817 validation 0.8948 test 0.8884
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [100], "embedding_dim": 2, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8507 validation 0.8772 test 0.8773
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [100, 20], "embedding_dim": 2, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8717 validation 0.8872 test 0.8840
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [], "embedding_dim": 2, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7004 validation 0.7728 test 0.7671
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [6604], "embedding_dim": 2, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8425 validation 0.8888 test 0.8815
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [6604, 3302], "embedding_dim": 2, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8539 validation 0.8952 test 0.8887
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [100], "embedding_dim": 2, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8263 validation 0.8748 test 0.8762
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [100, 20], "embedding_dim": 2, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8410 validation 0.8852 test 0.8809
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [], "embedding_dim": 3, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7424 validation 0.7896 test 0.7841
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [6604], "embedding_dim": 3, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.9167 validation 0.8912 test 0.8908
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [6604, 3302], "embedding_dim": 3, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.9244 validation 0.8808 test 0.8724
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [100], "embedding_dim": 3, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8916 validation 0.8812 test 0.8789
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [100, 20], "embedding_dim": 3, "dropout_rate": 0.2, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.9121 validation 0.8900 test 0.8870
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [], "embedding_dim": 3, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7424 validation 0.7896 test 0.7841
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [6604], "embedding_dim": 3, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.9063 validation 0.8916 test 0.8897
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [6604, 3302], "embedding_dim": 3, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.9117 validation 0.8864 test 0.8783
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [100], "embedding_dim": 3, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8831 validation 0.8744 test 0.8748
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [100, 20], "embedding_dim": 3, "dropout_rate": 0.3, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.9008 validation 0.8872 test 0.8844
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [], "embedding_dim": 3, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.7424 validation 0.7896 test 0.7841
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [6604], "embedding_dim": 3, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8868 validation 0.8864 test 0.8850
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [6604, 3302], "embedding_dim": 3, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8913 validation 0.8920 test 0.8849
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [100], "embedding_dim": 3, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8663 validation 0.8744 test 0.8760
# {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [100, 20], "embedding_dim": 3, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}
# Final accuracy: train 0.8810 validation 0.8828 test 0.8815
# Maximum Validation Accuracy from Step: 0.8952000141143799 with Key: {"vocab_size": 6604, "sequence_length": 660, "hidden_layers": [6604, 3302], "embedding_dim": 2, "dropout_rate": 0.4, "epochs": 5, "verbose": 0}

# %%
[(key, val) for key, val in results.items() if val > 0.895]

# %%
# for _ in range(10):
#    (
#        next_sequence_length,
#        next_vocab_size,
#        next_hidden_units,
#        next_embeddings,
#    ) = next_step(sequence_length, vocab_size, hidden_units, embeddings, 1.25)

#    if (
#        next_sequence_length == sequence_length
#        and next_vocab_size == vocab_size
#        and next_hidden_units == hidden_units
#        and next_embeddings == embeddings
#    ):
#        break

#    sequence_length = next_sequence_length
#    vocab_size = next_vocab_size
#    hidden_units = next_hidden_units
#    embeddings = next_embeddings
