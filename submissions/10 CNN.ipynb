# %% [markdown]
# # Lab 10

# %% [markdown]
# #### ``Objectives``
# 1. Implement a CNN to detect diabetic retinopathy (DR) from retina images taken using fundus photography under a variety of imaging conditions
# 2. Improve generalization performance and reduce overfitting using **image transformation** and **data augmentation** techniques
# 3. Tune hyperparameters of the CNN model

# %% [markdown]
# #### ``Motivation``

# %% [markdown]
# Diabetic retinopathy (DR) is an eye condition that  affects blood vessels in the retina. It can cause vision loss and blindness in people who have diabetes. Screening for DR allows earlier and more effective treatment options for millions of people.

# %% [markdown]
# #### ``Data``

# %% [markdown]
# In this assignment you will use a small dataset of retina images (`Download` links: [images](https://drive.google.com/drive/folders/1sdfUC64Un1iwuiHEehcbijxB54OhU_nd?usp=sharing) and [labels](https://drive.google.com/drive/folders/1MOlSJBZg7L1HtG5vHPt77ighRvQaGfDg?usp=sharing)). You will **build** and **train** a **CNN model** to predict whether or not to refer a patient for DR treatment using binarized severity of DR in patients: no referral if {No DR, mild} and referral if {moderate, severe, and proliferate DR}.
#
#
# <u>Note</u>: the original dataset is hosted by Kaggle [[Source]](https://www.kaggle.com/c/aptos2019-blindness-detection/).

# %% [markdown]
# Import the necessary libraries and make sure to replace IMAGE_PATH and LABEL_PATH with the path to the directories where you saved the data.

# %%
# standard
import pandas as pd
import numpy as np
import random
import os

# tf and keras
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras import models
from keras import layers

# plots
import seaborn as sns
import matplotlib.pyplot as plt

random.seed(2)
# %matplotlib inline

# FILL IN CODE HERE #
IMAGE_PATH = "CNN_images/"  # replace with your path
LABEL_PATH = "CNN_labels/"  # replace with your path

tf.get_logger().setLevel("INFO")
# tf.config.set_visible_devices([], "GPU")

# %% [markdown]
# At this point, you may ask yourself what the best CNN model that fits this data is. First, you will want to read through the data description in Kaggle (see the link to the original dataset above). Understanding what you are working with challenges you to write preprocessing code that uncovers your data's most helpful information.

# %% [markdown]
# ---
# ### Exercise 1 (8 points)

# %% [markdown]
# Read the data description from Kaggle and list (a) the source of images and (b) the labeling procedure.

# %% [markdown]
# *Written answer*:

# %% [markdown]
# **Source of Images**
# [Relevant Excerpts from the Kaggle description.]
#
# Millions of people suffer from diabetic retinopathy, the leading cause of blindness among working aged adults. Aravind Eye Hospital in India hopes to detect and prevent this disease among people living in rural areas where medical screening is difficult to conduct.   Aravind technicians traveled to these rural areas to capture images using fundus photography under a variety of imaging conditions.
#
# **Labeling Procedures**
#
# The images are reviewed by highly trained doctors who rate each image for the severity of diabetic retinopathy on a scale of 0 to 4:
# 1. No diapbetic retinopathy
# 2. Mild diabetic retinopathy
# 3. Severe diabetic retinopathy
# 4. Proliferative diabetic retinopathy (the more advanced stage when the retina starts growing new blood vessels)

# %% [markdown]
# ## Read data

# %% [markdown]
# Let's now explore our dataset. We will start with label inspection and continue with image visualization.

# %%
y = pd.read_csv(
    LABEL_PATH + 'labels.csv'
)

print('Shape of labels:', y.shape)
print('Unique diagnosis codes:', np.sort(y.diagnosis.unique()))
y.head()
# Out:
# Shape of labels: (200, 2)
# Unique diagnosis codes: [0 1 2 3 4]
#         id_code  diagnosis
# 0  000c1434d8d7          2
# 1  0024cdab0c1e          1
# 2  0083ee8054ee          4
# 3  00a8624548a9          2
# 4  00b74780d31d          2

# %% [markdown]
# There are 200 training images corrresponding to 5 different diabetic retinopathy (DR) diagnosis codes:
#
# * No DR (0)
# * mild (1)
# * moderate (2)
# * severe (3)
# * proliferate DR (4)

# %% [markdown]
# Image inspection:

# %%
# read image
indx=0
images = []

print('Sample of images in data:')
for idx, img in enumerate(os.listdir(IMAGE_PATH)):
    img = load_img(
    IMAGE_PATH + img)
    images.append(img)

nrows, ncols = 2,4 #print first 8 images
f, axs = plt.subplots(nrows, ncols, figsize=(20,10))
for i in range(nrows):
    for j in range(ncols):
        indx = i*nrows+j
        axs[i,j].imshow(images[indx])
# Out:
# Sample of images in data:

# %% [markdown]
# Like any real-world data set, you can see that these images have different sizes and focus. Later, you will use image transformation and data augmentation techniques to remove some of this variation.

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# The quality of the data determines how well a machine learning algorithm can learn. This section will apply some simple techniques to deal with class imbalance. We will then create training/validation/test datasets and perform image transformation and augmentation.

# %% [markdown]
# ---
# ### Exercise 2 (8 points)

# %% [markdown]
# Graph a histogram for the five classes of DR. Write down the percentage of the largest class in the written answer below.

# %%
# YOUR CODE HERE

y["diagnosis"].hist()
pd.DataFrame()
pd.DataFrame(
    [
        (x, sum(y["diagnosis"] == x), sum(y["diagnosis"] == x) / len(y) * 100)
        for x in np.sort(y["diagnosis"].unique())
    ],
    columns=["label", "count", "percentage"],
)
# Out:
#    label  count  percentage
# 0      0     82        41.0
# 1      1     18         9.0
# 2      2     73        36.5
# 3      3     12         6.0
# 4      4     15         7.5

# %% [markdown]
# *Written answer*:
#
# The largest class is class 0 (no diabetic retinopathy) comprising 41% of the sample population.)

# %% [markdown]
# ---

# %% [markdown]
# `Correct for data imbalance`

# %% [markdown]
# As you can see from the histogram above, our dataset is very imbalanced, which is common in healthcare, and it happens because some diseases are rare. The presence of imbalanced data hampers the detection of rare events as most classification methods implicitly assume a similar occurrence of classes and are designed to maximize the overall classification accuracy.
#
# We will correct for class imbalance in two ways:
#
#   * First, we will binarize the DR diagnosis as follows:
#      - 'no refer' are {No DR, mild}
#      - 'refer' are {Moderate, Severe, Proliferate}
#
#
#   * Second, we'll only take 80 random samples from the 'no refer' class and 80 from the 'refer' class.
#
# It is a crude method to deal with imbalanced data, but it will be good enough for this homework.

# %%
np.random.seed(1234)

no_refer = y[y.diagnosis.isin((0,1))]
refer = y[y.diagnosis.isin((2,3,4))]

# randomly draw 80 images from each classes
temp_no_refer = list(np.random.choice(
    no_refer.id_code,
    size=80,
    replace=False
))

temp_refer = list(np.random.choice(
    refer.id_code,
    size=80,
    replace=False
))

# %% [markdown]
# Next, we will use the **preprocess_data_part1()** function defined below to generate lists of images and labels (`images_mini` and `y_mini`) based on the values in the temp_no_refer and temp_refer lists.

# %%
def preprocess_data_part1(IMAGE_PATH, LABEL_PATH):
    """ Generate lists of images and labelsbased on temp_no_refer and temp_refer lists
    
    Params:
    -------
    IMAGE_PATH (str): path to directory with images.
    LABEL_PATH (str): path to directory with labels.
    
    Returns:
    --------
    images_mini  (np.ndarray): Images of shape (N, 224, 224, 3)
    y_mini (np.ndarray): Labels of shape (N,)    
    """
    y_mini = []
    images_mini = []

    # create lists of images and labels `images_mini` and `y_mini` 
    # based on temp_no_refer and temp_refer selections
    for idx, img in enumerate(os.listdir(IMAGE_PATH)):
        # read labels
        if img.split('.')[0] in temp_no_refer:
                y_mini.append(0)
        elif img.split('.')[0] in temp_refer:
                y_mini.append(1)
        else:
            continue

        
        # read image
        img = load_img(
            IMAGE_PATH + img,
            target_size=(224, 224)
        )
        
        # transform image to array
        img = img_to_array(img)

        # append to images
        images_mini.append(img)

    # stack images and trasnform to array
    images_mini = np.stack(images_mini)
    y_mini = np.array(y_mini).flatten() 
    
    return images_mini, y_mini

# %%
# generate images and labels based on preprocess_data_part1() function
images_mini, y_mini = preprocess_data_part1(IMAGE_PATH, LABEL_PATH)

print(f"images_mini shape {images_mini.shape}")
print(f"y_mini shape {y_mini.shape}")
# Out:
# images_mini shape (159, 224, 224, 3)
# y_mini shape (159,)

# %% [markdown]
# `Create train/validation/test data` and ``perform image tranformation and augmentation``

# %% [markdown]
# The next step in the data preprocessing part is to split the data into training, validation, and test sets. Once we have these partitions, we will apply image transformation and augmentations.
#
#
# To give you an idea of what image transformation and augmentation do, let's see an example applied to the first image in our mini data.

# %%
tf.random.set_seed(1234)

fig = plt.figure(figsize=(14, 12))

# pull first image from data
image = images_mini[0]

# plot original
ax = fig.add_subplot(1, 5, 1)
ax.imshow(array_to_img(image))
ax.set_title('Original', size=15);

# resize
ax = fig.add_subplot(1, 5, 2)
img_resize = tf.image.resize(image, size=(224, 224))
ax.imshow(array_to_img(img_resize))
ax.set_title('Step 1: Resize', size=15);


# adjust brightness
ax = fig.add_subplot(1, 5, 3)
img_bright = tf.image.adjust_brightness(img_resize, 0.3)
ax.imshow(array_to_img(img_bright))
ax.set_title('Step 2: Brightness', size=15);


# adjust contrast
ax = fig.add_subplot(1, 5, 4)
img_contrast = tf.image.adjust_contrast(img_bright, contrast_factor=3)
ax.imshow(array_to_img(img_contrast))
ax.set_title('Step 3: Contrast', size=15);


# flip left right
ax = fig.add_subplot(1, 5, 5)
img_flip = tf.image.flip_left_right(img_contrast)
ax.imshow(array_to_img(img_flip))
ax.set_title('Step 4: Flip left right', size=15);
# Out:
# 2022-07-06 12:47:42.062475: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-06 12:47:42.084899: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-06 12:47:42.085110: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-06 12:47:42.085564: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-06 12:47:42.086081: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-06 12:47:42.086283: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-06 12:47:42.086475: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-06 12:47:42.429833: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-06 12:47:42.430026: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-06 12:47:42.430178: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-06 12:47:42.430307: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 620 MB memory:  -> device: 0, name: NVIDIA RTX A5000, pci bus id: 0000:01:00.0, compute capability: 8.6

# %% [markdown]
# Next, we will define and run the **preprocess_data_part2()** function to create:
#
# * train/validation/test sets with split (0.6,0.2,0.2)
#
# * image transformation and augmentation, as follows:
#
# <u>Applied on training, validation and test sets</u>:
#   - resize to IMAGE_SIZE =(224,224) using tf.image.resize()
#   - normalize all pixel values to the range (0,1)
#
# <u>Applied on training set only</u> (note that this step will create additional/augmented copies of the training data):
#   - adjust brightness by adding DELTA=0.3 to the pixel values using tf.image.adjust_brighness()
#   - adjust contrast to CONTRAST_FACTOR=3 using tf.image.adjust_contrast()
#   - flip left right using tf.image.flip_left_right()

# %% [markdown]
# The quantity and diversity of data gathered have a significant impact on the results of a CNN model. One can apply augmentations to artificially inflate the training dataset by warping the original data such that their label does not change. These augmentations can significantly improve learning results without collecting new data.

# %%
IMAGE_SIZE = (224, 224)
CONTRAST_FACTOR = 3
DELTA = 0.3

def preprocess_data_part2(images, y, split=(0.6,0.2,0.2)):
    """ Split data into train, validation and test sets; apply transformaions and augmentations
    
    Params:
    -------
    images  (np.ndarray): Images of shape (N, 224, 224, 3)
    y (np.ndarray): Labels of shape (N,)   
    split (tuple): 3 values summing to 1 defining split of train, validation and test sets
    
    Returns:
    --------
    X_train (np.ndarray): Train images of shape (N_train, 224, 224, 3)
    y_train (np.ndarray): Train labels of shape (N_train,)
    X_val (np.ndarray): Val images of shape (N_val, 224, 224, 3)
    y_val (np.ndarray): Val labels of shape (N_val,)
    X_test (np.ndarray): Test images of shape (N_test, 224, 224, 3)
    y_test (np.ndarray): Test labels of shape (N_test,)
    
    """
    
    ### create train/validation/test sets ###
    #########################################
    # NOTE: Each time you run this cell, you'll re-shuffle the data. The ordering will be the same due to the random seed generator 
    tf.random.set_seed(1234)
    np.random.seed(1234)
    shuffle = np.random.permutation(np.arange(images.shape[0]))
    images, y = images[shuffle], y[shuffle]
    
    splits = np.multiply(len(images_mini), split).astype(int)
    X_train, X_val, X_test = np.split(images_mini, [splits[0], splits[0]+splits[1]])
    y_train, y_val, y_test = np.split(y_mini, [splits[0], splits[0]+splits[1]])
    
    ### image transformation on training, validation, and test data ###
    ###################################################################
    # image resize
    X_train = tf.image.resize(X_train, size=IMAGE_SIZE)
    X_val = tf.image.resize(X_val, size=IMAGE_SIZE)
    X_test = tf.image.resize(X_test, size=IMAGE_SIZE)
    
    # rescale image to [0,1], i.e., greyscale
    X_train = X_train/255.0
    X_val = X_val/255.0
    X_test = X_test/255.0
    
    
    ### image augmentation on training data ###
    ###########################################
    # adjust brightness
    X_train_augm = tf.image.adjust_brightness(X_train, delta=DELTA)
    
    # adjust contrast
    X_train_augm = tf.image.adjust_contrast(X_train_augm, contrast_factor=CONTRAST_FACTOR)

    # random flip
    X_train_augm = tf.image.random_flip_left_right(X_train_augm)
    
    # concatenate original X_train and augmented X_train data
    X_train = tf.concat([X_train, X_train_augm],axis=0)
    
    # concatenate y_train (note the label is preserved)
    y_train_augm = y_train
    y_train = tf.concat([y_train, y_train_augm],axis=0)
    
    # shuffle X_train and y_train, i.e., shuffle two tensors in the same order
    shuffle = tf.random.shuffle(tf.range(tf.shape(X_train)[0], dtype=tf.int32))
    X_train = tf.gather(X_train, shuffle)
    y_train = tf.gather(y_train, shuffle).numpy() #also transforms y_train to numpy array
    
    return X_train, y_train, X_val, y_val, X_test, y_test

# %% [markdown]
# Let's sanity check our implementation of the preprocess_data_part2() function by printing the shape of (X,y) from train, validation and test sets.

# %%
X_train, y_train, X_val, y_val, X_test, y_test = preprocess_data_part2(
    images_mini,
    y_mini,
    split=(0.6,0.2,0.2)
)

print(f"X_train shape {X_train.shape}")
print(f"y_train shape {y_train.shape}")
print(f"X_val shape {X_val.shape}")
print(f"y_val shape {y_val.shape}")
print(f"X_test shape {X_test.shape}")
print(f"y_test shape {y_test.shape}")
# Out:
# X_train shape (190, 224, 224, 3)
# y_train shape (190,)
# X_val shape (31, 224, 224, 3)
# y_val shape (31,)
# X_test shape (33, 224, 224, 3)
# y_test shape (33,)

# %% [markdown]
# Let's also print out the first 8 train and validation examples with the label of each example as the title.

# %%
# print taining data
print('Print training data examples:')
nrows, ncols = 1,4 #print first 4 images
f, axs = plt.subplots(nrows, ncols, figsize=(14,12))
for i in range(ncols):
    axs[i].imshow(array_to_img(X_train[i]))
    axs[i].set(title=y_train[i])
# Out:
# Print training data examples:

# %%
# print test data
print('Print validation data examples:')
nrows, ncols = 1,4 #print first 4 images
f, axs = plt.subplots(nrows, ncols, figsize=(14,12))
for i in range(ncols):
    axs[i].imshow(array_to_img(X_val[i]))
    axs[i].set(title=y_val[i])
# Out:
# Print validation data examples:

# %% [markdown]
# ---
# ### Exercise 3 (8 points)
#
# We've split the data into train, validation, and test sets. Explain the purpose of each of these.

# %% [markdown]
# *Written answer*:
#
# The `train` set is used to train the model.
# The `validation` set is used to evaluate how the model performs on unseen data so that we can optimize hyperparameters.
# The `test` is used to evaluate our final model on unseen data that was not used to train the model or to develop hyperparameters.

# %% [markdown]
# ___

# %% [markdown]
# ## Model

# %% [markdown]
# Our objective is to build and train a CNN model to refer patients to doctors based on the severity of DR seen in these images. We are interested in exploring binary classification of 'no refer' and 'refer'.
#
# <u>The architecture of our CNN model is as follows</u>:
#
# 1. the model receives input images of size 224 x 224 x 3 (the images have three color channels)
# 2. the input data goes through two convolutional layers that have kernels of size 5 x 5
# 3. the first convolution has 32 output feature maps, and the second one has 64
# 4. each convolution layer is followed by a max-pooling layer (this will reduce the size of the feature maps)
# 5. the last two layers of the model are fully connected with a droput layer in between
#
# For each convolution we use strides=(1,1) to preserve the dimension of the inputs in the resulting feature maps. For the pooling layers, we set strides=(2,2) to subsample the image and shrink the size of the output feature maps. For the dropout layer, we set the probability of dropping input units during training to 0.5.
#
#
# We will implement this architecture using TensorFlow Keras API.

# %% [markdown]
# ``Build model``

# %%
model = tf.keras.Sequential()

# add first convolution layer to the model
model.add(tf.keras.layers.Conv2D(
    filters=32,
    kernel_size=(5, 5),
    strides=(1, 1),
    padding='same',
    data_format='channels_last',
    name='conv_1',
    activation='relu'))


# add a max pooling layer with pool size (2,2) and strides of 2
# (this will reduce the spatial dimensions by half)
model.add(tf.keras.layers.MaxPool2D(
    pool_size=(2, 2),
    name='pool_1'))


# add second convolutional layer
model.add(tf.keras.layers.Conv2D(
    filters=64,
    kernel_size=(5, 5),
    strides=(1, 1),
    padding='same',
    name='conv_2',
    activation='relu'))

# add second max pooling layer with pool size (2,2) and strides of 2
# (this will further reduce the spatial dimensions by half)
model.add(tf.keras.layers.MaxPool2D(
    pool_size=(2, 2), name='pool_2')
)


# add a fully connected layer (need to flatten the output of the previous layers first)
model.add(tf.keras.layers.Flatten()) 
model.add(tf.keras.layers.Dense(
    units=1024,
    name='fc_1', 
    activation='relu'))

# add dropout layer
model.add(tf.keras.layers.Dropout(
    rate=0.5))

# add the last fully connected layer
# this last layer sets the activation function to "None" in order to output the logits 
# note that passing activation = "sigmoid" will return class memembership probabilities but
# in TensorFlow logits are prefered for numerical stability
# set units=1 to get a single output unit (remember it's a binary classification problem)
model.add(tf.keras.layers.Dense(
    units=1,
    name='fc_2',
    activation=None))


# build model and print summary
tf.random.set_seed(1)
model.build(input_shape=(None, 224, 224, 3))
model.summary()
# Out:
# 2022-07-06 13:05:57.133149: W tensorflow/core/common_runtime/bfc_allocator.cc:457] Allocator (GPU_0_bfc) ran out of memory trying to allocate 784.00MiB (rounded to 822083584)requested by op RandomUniform
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2022-07-06 13:05:57.133240: I tensorflow/core/common_runtime/bfc_allocator.cc:1004] BFCAllocator dump for GPU_0_bfc
# 2022-07-06 13:05:57.133278: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (256): 	Total Chunks: 15, Chunks in use: 15. 3.8KiB allocated for chunks. 3.8KiB in use in bin. 440B client-requested in use in bin.
# 2022-07-06 13:05:57.133306: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (512): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-07-06 13:05:57.133332: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (1024): 	Total Chunks: 1, Chunks in use: 1. 1.2KiB allocated for chunks. 1.2KiB in use in bin. 1.0KiB client-requested in use in bin.
# 2022-07-06 13:05:57.133355: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (2048): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-07-06 13:05:57.133376: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (4096): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-07-06 13:05:57.133400: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (8192): 	Total Chunks: 1, Chunks in use: 1. 9.5KiB allocated for chunks. 9.5KiB in use in bin. 9.4KiB client-requested in use in bin.
# 2022-07-06 13:05:57.133426: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (16384): 	Total Chunks: 1, Chunks in use: 0. 17.8KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-07-06 13:05:57.133449: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (32768): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-07-06 13:05:57.133473: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (65536): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-07-06 13:05:57.133516: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (131072): 	Total Chunks: 1, Chunks in use: 1. 200.0KiB allocated for chunks. 200.0KiB in use in bin. 200.0KiB client-requested in use in bin.
# 2022-07-06 13:05:57.133558: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (262144): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-07-06 13:05:57.133605: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (524288): 	Total Chunks: 5, Chunks in use: 4. 2.84MiB allocated for chunks. 2.30MiB in use in bin. 2.30MiB client-requested in use in bin.
# 2022-07-06 13:05:57.133639: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (1048576): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-07-06 13:05:57.133662: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (2097152): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-07-06 13:05:57.133686: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (4194304): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-07-06 13:05:57.133708: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (8388608): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-07-06 13:05:57.133736: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (16777216): 	Total Chunks: 2, Chunks in use: 2. 36.75MiB allocated for chunks. 36.75MiB in use in bin. 36.75MiB client-requested in use in bin.
# 2022-07-06 13:05:57.133760: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-07-06 13:05:57.133782: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-07-06 13:05:57.133821: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (134217728): 	Total Chunks: 3, Chunks in use: 1. 580.43MiB allocated for chunks. 145.85MiB in use in bin. 109.10MiB client-requested in use in bin.
# 2022-07-06 13:05:57.133845: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (268435456): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-07-06 13:05:57.133870: I tensorflow/core/common_runtime/bfc_allocator.cc:1027] Bin for 784.00MiB was 256.00MiB, Chunk State:
# 2022-07-06 13:05:57.133892: I tensorflow/core/common_runtime/bfc_allocator.cc:1040] Next region of size 650379264
# 2022-07-06 13:05:57.133918: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b8000000 of size 256 next 4
# 2022-07-06 13:05:57.133939: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b8000100 of size 256 next 6
# 2022-07-06 13:05:57.133957: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b8000200 of size 256 next 14
# 2022-07-06 13:05:57.133977: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b8000300 of size 256 next 9
# 2022-07-06 13:05:57.133996: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b8000400 of size 256 next 16
# 2022-07-06 13:05:57.134014: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b8000500 of size 256 next 26
# 2022-07-06 13:05:57.134031: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b8000600 of size 256 next 17
# 2022-07-06 13:05:57.134050: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b8000700 of size 256 next 21
# 2022-07-06 13:05:57.134069: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b8000800 of size 256 next 18
# 2022-07-06 13:05:57.134087: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b8000900 of size 256 next 20
# 2022-07-06 13:05:57.134105: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b8000a00 of size 256 next 11
# 2022-07-06 13:05:57.134125: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b8000b00 of size 256 next 12
# 2022-07-06 13:05:57.134144: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b8000c00 of size 256 next 23
# 2022-07-06 13:05:57.134164: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b8000d00 of size 256 next 27
# 2022-07-06 13:05:57.134193: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b8000e00 of size 256 next 28
# 2022-07-06 13:05:57.134228: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] Free  at 7f18b8000f00 of size 18176 next 24
# 2022-07-06 13:05:57.134263: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b8005600 of size 9728 next 22
# 2022-07-06 13:05:57.134299: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] Free  at 7f18b8007c00 of size 570368 next 1
# 2022-07-06 13:05:57.134337: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b8093000 of size 1280 next 2
# 2022-07-06 13:05:57.134415: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b8093500 of size 602112 next 3
# 2022-07-06 13:05:57.134449: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b8126500 of size 602112 next 5
# 2022-07-06 13:05:57.134471: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b81b9500 of size 602112 next 7
# 2022-07-06 13:05:57.134505: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b824c500 of size 602112 next 8
# 2022-07-06 13:05:57.134550: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b82df500 of size 204800 next 25
# 2022-07-06 13:05:57.134590: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] Free  at 7f18b8311500 of size 191266816 next 15
# 2022-07-06 13:05:57.134631: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18c3979500 of size 18665472 next 13
# 2022-07-06 13:05:57.134663: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18c4b46500 of size 19869696 next 10
# 2022-07-06 13:05:57.134691: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18c5e39500 of size 152936448 next 19
# 2022-07-06 13:05:57.134731: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] Free  at 7f18cf013500 of size 264424192 next 18446744073709551615
# 2022-07-06 13:05:57.134763: I tensorflow/core/common_runtime/bfc_allocator.cc:1065]      Summary of in-use Chunks by size:
# 2022-07-06 13:05:57.134799: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 15 Chunks of size 256 totalling 3.8KiB
# 2022-07-06 13:05:57.134846: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 1280 totalling 1.2KiB
# 2022-07-06 13:05:57.134874: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 9728 totalling 9.5KiB
# 2022-07-06 13:05:57.134900: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 204800 totalling 200.0KiB
# 2022-07-06 13:05:57.134923: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 4 Chunks of size 602112 totalling 2.30MiB
# 2022-07-06 13:05:57.134947: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 18665472 totalling 17.80MiB
# 2022-07-06 13:05:57.134982: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 19869696 totalling 18.95MiB
# 2022-07-06 13:05:57.135028: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 152936448 totalling 145.85MiB
# 2022-07-06 13:05:57.135078: I tensorflow/core/common_runtime/bfc_allocator.cc:1072] Sum Total of in-use chunks: 185.11MiB
# 2022-07-06 13:05:57.135125: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] total_region_allocated_bytes_: 650379264 memory_limit_: 650379264 available bytes: 0 curr_region_allocation_bytes_: 1300758528
# 2022-07-06 13:05:57.135166: I tensorflow/core/common_runtime/bfc_allocator.cc:1080] Stats:
# Limit:                       650379264
# InUse:                       194099712
# MaxInUse:                    649780992
# NumAllocs:                          84
# MaxAllocSize:                171601920
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2022-07-06 13:05:57.135205: W tensorflow/core/common_runtime/bfc_allocator.cc:468] *____________________________*************************xxxxxx________________________________________
# 2022-07-06 13:05:57.135312: W tensorflow/core/framework/op_kernel.cc:1692] OP_REQUIRES failed at random_op.cc:74 : Resource exhausted: OOM when allocating tensor with shape[200704,1024] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 2022-07-06 13:06:07.144652: W tensorflow/core/common_runtime/bfc_allocator.cc:457] Allocator (GPU_0_bfc) ran out of memory trying to allocate 784.00MiB (rounded to 822083584)requested by op RandomUniform
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2022-07-06 13:06:07.144741: I tensorflow/core/common_runtime/bfc_allocator.cc:1004] BFCAllocator dump for GPU_0_bfc
# 2022-07-06 13:06:07.144779: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (256): 	Total Chunks: 15, Chunks in use: 15. 3.8KiB allocated for chunks. 3.8KiB in use in bin. 440B client-requested in use in bin.
# 2022-07-06 13:06:07.144807: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (512): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-07-06 13:06:07.144834: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (1024): 	Total Chunks: 1, Chunks in use: 1. 1.2KiB allocated for chunks. 1.2KiB in use in bin. 1.0KiB client-requested in use in bin.
# 2022-07-06 13:06:07.144857: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (2048): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-07-06 13:06:07.144878: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (4096): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-07-06 13:06:07.144903: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (8192): 	Total Chunks: 1, Chunks in use: 1. 9.5KiB allocated for chunks. 9.5KiB in use in bin. 9.4KiB client-requested in use in bin.
# 2022-07-06 13:06:07.144929: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (16384): 	Total Chunks: 1, Chunks in use: 0. 17.8KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-07-06 13:06:07.144952: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (32768): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-07-06 13:06:07.144975: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (65536): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-07-06 13:06:07.145001: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (131072): 	Total Chunks: 1, Chunks in use: 1. 200.0KiB allocated for chunks. 200.0KiB in use in bin. 200.0KiB client-requested in use in bin.
# 2022-07-06 13:06:07.145026: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (262144): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-07-06 13:06:07.145051: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (524288): 	Total Chunks: 5, Chunks in use: 4. 2.84MiB allocated for chunks. 2.30MiB in use in bin. 2.30MiB client-requested in use in bin.
# 2022-07-06 13:06:07.145074: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (1048576): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-07-06 13:06:07.145095: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (2097152): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-07-06 13:06:07.145118: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (4194304): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-07-06 13:06:07.145141: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (8388608): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-07-06 13:06:07.145168: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (16777216): 	Total Chunks: 2, Chunks in use: 2. 36.75MiB allocated for chunks. 36.75MiB in use in bin. 36.75MiB client-requested in use in bin.
# 2022-07-06 13:06:07.145190: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-07-06 13:06:07.145214: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-07-06 13:06:07.145242: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (134217728): 	Total Chunks: 3, Chunks in use: 1. 580.43MiB allocated for chunks. 145.85MiB in use in bin. 109.10MiB client-requested in use in bin.
# 2022-07-06 13:06:07.145265: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (268435456): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-07-06 13:06:07.145289: I tensorflow/core/common_runtime/bfc_allocator.cc:1027] Bin for 784.00MiB was 256.00MiB, Chunk State:
# 2022-07-06 13:06:07.145310: I tensorflow/core/common_runtime/bfc_allocator.cc:1040] Next region of size 650379264
# 2022-07-06 13:06:07.145336: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b8000000 of size 256 next 4
# 2022-07-06 13:06:07.145357: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b8000100 of size 256 next 6
# 2022-07-06 13:06:07.145375: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b8000200 of size 256 next 14
# 2022-07-06 13:06:07.145394: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b8000300 of size 256 next 9
# 2022-07-06 13:06:07.145413: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b8000400 of size 256 next 16
# 2022-07-06 13:06:07.145430: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b8000500 of size 256 next 26
# 2022-07-06 13:06:07.145447: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b8000600 of size 256 next 17
# 2022-07-06 13:06:07.145466: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b8000700 of size 256 next 21
# 2022-07-06 13:06:07.145484: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b8000800 of size 256 next 18
# 2022-07-06 13:06:07.145502: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b8000900 of size 256 next 20
# 2022-07-06 13:06:07.145539: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b8000a00 of size 256 next 11
# 2022-07-06 13:06:07.145559: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b8000b00 of size 256 next 12
# 2022-07-06 13:06:07.145578: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b8000c00 of size 256 next 23
# 2022-07-06 13:06:07.145595: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b8000d00 of size 256 next 27
# 2022-07-06 13:06:07.145613: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b8000e00 of size 256 next 28
# 2022-07-06 13:06:07.145632: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] Free  at 7f18b8000f00 of size 18176 next 24
# 2022-07-06 13:06:07.145652: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b8005600 of size 9728 next 22
# 2022-07-06 13:06:07.145671: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] Free  at 7f18b8007c00 of size 570368 next 1
# 2022-07-06 13:06:07.145691: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b8093000 of size 1280 next 2
# 2022-07-06 13:06:07.145712: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b8093500 of size 602112 next 3
# 2022-07-06 13:06:07.145732: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b8126500 of size 602112 next 5
# 2022-07-06 13:06:07.145754: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b81b9500 of size 602112 next 7
# 2022-07-06 13:06:07.145773: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b824c500 of size 602112 next 8
# 2022-07-06 13:06:07.145793: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18b82df500 of size 204800 next 25
# 2022-07-06 13:06:07.145813: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] Free  at 7f18b8311500 of size 191266816 next 15
# 2022-07-06 13:06:07.145841: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18c3979500 of size 18665472 next 13
# 2022-07-06 13:06:07.145862: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18c4b46500 of size 19869696 next 10
# 2022-07-06 13:06:07.145883: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f18c5e39500 of size 152936448 next 19
# 2022-07-06 13:06:07.145909: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] Free  at 7f18cf013500 of size 264424192 next 18446744073709551615
# 2022-07-06 13:06:07.145930: I tensorflow/core/common_runtime/bfc_allocator.cc:1065]      Summary of in-use Chunks by size:
# 2022-07-06 13:06:07.145960: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 15 Chunks of size 256 totalling 3.8KiB
# 2022-07-06 13:06:07.145990: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 1280 totalling 1.2KiB
# 2022-07-06 13:06:07.146012: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 9728 totalling 9.5KiB
# 2022-07-06 13:06:07.146041: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 204800 totalling 200.0KiB
# 2022-07-06 13:06:07.146063: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 4 Chunks of size 602112 totalling 2.30MiB
# 2022-07-06 13:06:07.146092: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 18665472 totalling 17.80MiB
# 2022-07-06 13:06:07.146117: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 19869696 totalling 18.95MiB
# 2022-07-06 13:06:07.146145: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 152936448 totalling 145.85MiB
# 2022-07-06 13:06:07.146170: I tensorflow/core/common_runtime/bfc_allocator.cc:1072] Sum Total of in-use chunks: 185.11MiB
# 2022-07-06 13:06:07.146194: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] total_region_allocated_bytes_: 650379264 memory_limit_: 650379264 available bytes: 0 curr_region_allocation_bytes_: 1300758528
# 2022-07-06 13:06:07.146230: I tensorflow/core/common_runtime/bfc_allocator.cc:1080] Stats:
# Limit:                       650379264
# InUse:                       194099712
# MaxInUse:                    649780992
# NumAllocs:                          84
# MaxAllocSize:                171601920
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2022-07-06 13:06:07.146261: W tensorflow/core/common_runtime/bfc_allocator.cc:468] *____________________________*************************xxxxxx________________________________________
# 2022-07-06 13:06:07.146358: W tensorflow/core/framework/op_kernel.cc:1692] OP_REQUIRES failed at random_op.cc:74 : Resource exhausted: OOM when allocating tensor with shape[200704,1024] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Input In [21], in <cell line: 61>()
#      59 # build model and print summary
#      60 tf.random.set_seed(1)
# ---> 61 model.build(input_shape=(None, 224, 224, 3))
#      62 model.summary()
#
# File /opt/conda/lib/python3.9/site-packages/keras/engine/sequential.py:345, in Sequential.build(self, input_shape)
#     343     input_shape = tuple(input_shape)
#     344     self._build_input_shape = input_shape
# --> 345     super(Sequential, self).build(input_shape)
#     346 self.built = True
#
# File /opt/conda/lib/python3.9/site-packages/keras/engine/training.py:413, in Model.build(self, input_shape)
#     410   raise ValueError('You can only call `build` on a model if its `call` '
#     411                    'method accepts an `inputs` argument.')
#     412 try:
# --> 413   self.call(x, **kwargs)
#     414 except (tf.errors.InvalidArgumentError, TypeError):
#     415   raise ValueError('You cannot build your model by calling `build` '
#     416                    'if your layers do not support float type inputs. '
#     417                    'Instead, in order to instantiate and build your '
#     418                    'model, `call` your model on real tensor data (of '
#     419                    'the correct dtype).')
#
# File /opt/conda/lib/python3.9/site-packages/keras/engine/sequential.py:383, in Sequential.call(self, inputs, training, mask)
#     380 if 'training' in argspec:
#     381   kwargs['training'] = training
# --> 383 outputs = layer(inputs, **kwargs)
#     385 if len(tf.nest.flatten(outputs)) != 1:
#     386   raise ValueError(SINGLE_LAYER_OUTPUT_ERROR_MSG)
#
# File /opt/conda/lib/python3.9/site-packages/keras/engine/base_layer.py:1030, in Layer.__call__(self, *args, **kwargs)
#    1028 with tf.name_scope(name_scope):
#    1029   if not self.built:
# -> 1030     self._maybe_build(inputs)
#    1032   if self._autocast:
#    1033     inputs = self._maybe_cast_inputs(inputs, input_list)
#
# File /opt/conda/lib/python3.9/site-packages/keras/engine/base_layer.py:2659, in Layer._maybe_build(self, inputs)
#    2654 if not hasattr(self.build, '_is_default'):
#    2655   # Any setup work performed only once should happen in an `init_scope`
#    2656   # to avoid creating symbolic Tensors that will later pollute any eager
#    2657   # operations.
#    2658   with tf_utils.maybe_init_scope(self):
# -> 2659     self.build(input_shapes)  # pylint:disable=not-callable
#    2660 # We must set also ensure that the layer is marked as built, and the build
#    2661 # shape is stored since user defined build functions may not be calling
#    2662 # `super.build()`
#    2663 Layer.build(self, input_shapes)
#
# File /opt/conda/lib/python3.9/site-packages/keras/layers/core.py:1178, in Dense.build(self, input_shape)
#    1175   raise ValueError('The last dimension of the inputs to `Dense` '
#    1176                    'should be defined. Found `None`.')
#    1177 self.input_spec = InputSpec(min_ndim=2, axes={-1: last_dim})
# -> 1178 self.kernel = self.add_weight(
#    1179     'kernel',
#    1180     shape=[last_dim, self.units],
#    1181     initializer=self.kernel_initializer,
#    1182     regularizer=self.kernel_regularizer,
#    1183     constraint=self.kernel_constraint,
#    1184     dtype=self.dtype,
#    1185     trainable=True)
#    1186 if self.use_bias:
#    1187   self.bias = self.add_weight(
#    1188       'bias',
#    1189       shape=[self.units,],
#    (...)
#    1193       dtype=self.dtype,
#    1194       trainable=True)
#
# File /opt/conda/lib/python3.9/site-packages/keras/engine/base_layer.py:647, in Layer.add_weight(self, name, shape, dtype, initializer, regularizer, trainable, constraint, use_resource, synchronization, aggregation, **kwargs)
#     642     tf_logging.warning(
#     643         '`caching_device` does not work with mixed precision API. Ignoring '
#     644         'user specified `caching_device`.')
#     645     caching_device = None
# --> 647 variable = self._add_variable_with_custom_getter(
#     648     name=name,
#     649     shape=shape,
#     650     # TODO(allenl): a `make_variable` equivalent should be added as a
#     651     # `Trackable` method.
#     652     getter=getter,
#     653     # Manage errors in Layer rather than Trackable.
#     654     overwrite=True,
#     655     initializer=initializer,
#     656     dtype=dtype,
#     657     constraint=constraint,
#     658     trainable=trainable,
#     659     use_resource=use_resource,
#     660     collections=collections_arg,
#     661     synchronization=synchronization,
#     662     aggregation=aggregation,
#     663     caching_device=caching_device)
#     664 if regularizer is not None:
#     665   # TODO(fchollet): in the future, this should be handled at the
#     666   # level of variable creation, and weight regularization losses
#     667   # should be variable attributes.
#     668   name_in_scope = variable.name[:variable.name.find(':')]
#
# File /opt/conda/lib/python3.9/site-packages/tensorflow/python/training/tracking/base.py:813, in Trackable._add_variable_with_custom_getter(self, name, shape, dtype, initializer, getter, overwrite, **kwargs_for_getter)
#     803   if (checkpoint_initializer is not None and
#     804       not (isinstance(initializer, CheckpointInitialValueCallable) and
#     805            (initializer.restore_uid > checkpoint_initializer.restore_uid))):
#    (...)
#     810     # then we'll catch that when we call _track_trackable. So this is
#     811     # "best effort" to set the initializer with the highest restore UID.
#     812     initializer = checkpoint_initializer
# --> 813 new_variable = getter(
#     814     name=name,
#     815     shape=shape,
#     816     dtype=dtype,
#     817     initializer=initializer,
#     818     **kwargs_for_getter)
#     820 # If we set an initializer and the variable processed it, tracking will not
#     821 # assign again. It will add this variable to our dependencies, and if there
#     822 # is a non-trivial restoration queued, it will handle that. This also
#     823 # handles slot variables.
#     824 if not overwrite or isinstance(new_variable, Trackable):
#
# File /opt/conda/lib/python3.9/site-packages/keras/engine/base_layer_utils.py:117, in make_variable(name, shape, dtype, initializer, trainable, caching_device, validate_shape, constraint, use_resource, collections, synchronization, aggregation, partitioner)
#     112   use_resource = True
#     113 # In theory, in `use_resource` is True and `collections` is empty
#     114 # (that is to say, in TF2), we can use tf.Variable.
#     115 # However, this breaks legacy (Estimator) checkpoints
#     116 # because it changes variable names. Remove this when V1 is fully deprecated.
# --> 117 return tf.compat.v1.Variable(
#     118     initial_value=init_val,
#     119     name=name,
#     120     trainable=trainable,
#     121     caching_device=caching_device,
#     122     dtype=variable_dtype,
#     123     validate_shape=validate_shape,
#     124     constraint=constraint,
#     125     use_resource=use_resource,
#     126     collections=collections,
#     127     synchronization=synchronization,
#     128     aggregation=aggregation,
#     129     shape=variable_shape if variable_shape else None)
#
# File /opt/conda/lib/python3.9/site-packages/tensorflow/python/ops/variables.py:266, in VariableMetaclass.__call__(cls, *args, **kwargs)
#     264 def __call__(cls, *args, **kwargs):
#     265   if cls is VariableV1:
# --> 266     return cls._variable_v1_call(*args, **kwargs)
#     267   elif cls is Variable:
#     268     return cls._variable_v2_call(*args, **kwargs)
#
# File /opt/conda/lib/python3.9/site-packages/tensorflow/python/ops/variables.py:212, in VariableMetaclass._variable_v1_call(cls, initial_value, trainable, collections, validate_shape, caching_device, name, variable_def, dtype, expected_shape, import_scope, constraint, use_resource, synchronization, aggregation, shape)
#     210 if aggregation is None:
#     211   aggregation = VariableAggregation.NONE
# --> 212 return previous_getter(
#     213     initial_value=initial_value,
#     214     trainable=trainable,
#     215     collections=collections,
#     216     validate_shape=validate_shape,
#     217     caching_device=caching_device,
#     218     name=name,
#     219     variable_def=variable_def,
#     220     dtype=dtype,
#     221     expected_shape=expected_shape,
#     222     import_scope=import_scope,
#     223     constraint=constraint,
#     224     use_resource=use_resource,
#     225     synchronization=synchronization,
#     226     aggregation=aggregation,
#     227     shape=shape)
#
# File /opt/conda/lib/python3.9/site-packages/tensorflow/python/ops/variables.py:205, in VariableMetaclass._variable_v1_call.<locals>.<lambda>(**kwargs)
#     188 def _variable_v1_call(cls,
#     189                       initial_value=None,
#     190                       trainable=None,
#    (...)
#     202                       aggregation=VariableAggregation.NONE,
#     203                       shape=None):
#     204   """Call on Variable class. Useful to force the signature."""
# --> 205   previous_getter = lambda **kwargs: default_variable_creator(None, **kwargs)
#     206   for _, getter in ops.get_default_graph()._variable_creator_stack:  # pylint: disable=protected-access
#     207     previous_getter = _make_getter(getter, previous_getter)
#
# File /opt/conda/lib/python3.9/site-packages/tensorflow/python/ops/variable_scope.py:2612, in default_variable_creator(next_creator, **kwargs)
#    2610 if use_resource:
#    2611   distribute_strategy = kwargs.get("distribute_strategy", None)
# -> 2612   return resource_variable_ops.ResourceVariable(
#    2613       initial_value=initial_value,
#    2614       trainable=trainable,
#    2615       collections=collections,
#    2616       validate_shape=validate_shape,
#    2617       caching_device=caching_device,
#    2618       name=name,
#    2619       dtype=dtype,
#    2620       constraint=constraint,
#    2621       variable_def=variable_def,
#    2622       import_scope=import_scope,
#    2623       distribute_strategy=distribute_strategy,
#    2624       synchronization=synchronization,
#    2625       aggregation=aggregation,
#    2626       shape=shape)
#    2627 else:
#    2628   return variables.RefVariable(
#    2629       initial_value=initial_value,
#    2630       trainable=trainable,
#    (...)
#    2641       aggregation=aggregation,
#    2642       shape=shape)
#
# File /opt/conda/lib/python3.9/site-packages/tensorflow/python/ops/variables.py:270, in VariableMetaclass.__call__(cls, *args, **kwargs)
#     268   return cls._variable_v2_call(*args, **kwargs)
#     269 else:
# --> 270   return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#
# File /opt/conda/lib/python3.9/site-packages/tensorflow/python/ops/resource_variable_ops.py:1602, in ResourceVariable.__init__(self, initial_value, trainable, collections, validate_shape, caching_device, name, dtype, variable_def, import_scope, constraint, distribute_strategy, synchronization, aggregation, shape)
#    1600   self._init_from_proto(variable_def, import_scope=import_scope)
#    1601 else:
# -> 1602   self._init_from_args(
#    1603       initial_value=initial_value,
#    1604       trainable=trainable,
#    1605       collections=collections,
#    1606       caching_device=caching_device,
#    1607       name=name,
#    1608       dtype=dtype,
#    1609       constraint=constraint,
#    1610       synchronization=synchronization,
#    1611       aggregation=aggregation,
#    1612       shape=shape,
#    1613       distribute_strategy=distribute_strategy)
#
# File /opt/conda/lib/python3.9/site-packages/tensorflow/python/ops/resource_variable_ops.py:1740, in ResourceVariable._init_from_args(self, initial_value, trainable, collections, caching_device, name, dtype, constraint, synchronization, aggregation, distribute_strategy, shape)
#    1738 with ops.name_scope("Initializer"), device_context_manager(None):
#    1739   if init_from_fn:
# -> 1740     initial_value = initial_value()
#    1741   if isinstance(initial_value, trackable.CheckpointInitialValue):
#    1742     self._maybe_initialize_trackable()
#
# File /opt/conda/lib/python3.9/site-packages/keras/initializers/initializers_v2.py:517, in VarianceScaling.__call__(self, shape, dtype, **kwargs)
#     515 else:
#     516   limit = math.sqrt(3.0 * scale)
# --> 517   return self._random_generator.random_uniform(shape, -limit, limit, dtype)
#
# File /opt/conda/lib/python3.9/site-packages/keras/initializers/initializers_v2.py:972, in _RandomGenerator.random_uniform(self, shape, minval, maxval, dtype)
#     970 else:
#     971   op = tf.random.uniform
# --> 972 return op(
#     973     shape=shape, minval=minval, maxval=maxval, dtype=dtype, seed=self.seed)
#
# File /opt/conda/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:206, in add_dispatch_support.<locals>.wrapper(*args, **kwargs)
#     204 """Call target, and fall back on dispatchers if there is a TypeError."""
#     205 try:
# --> 206   return target(*args, **kwargs)
#     207 except (TypeError, ValueError):
#     208   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#     209   # TypeError, when given unexpected types.  So we need to catch both.
#     210   result = dispatch(wrapper, args, kwargs)
#
# File /opt/conda/lib/python3.9/site-packages/tensorflow/python/ops/random_ops.py:309, in random_uniform(shape, minval, maxval, dtype, seed, name)
#     306   result = gen_random_ops.random_uniform_int(
#     307       shape, minval, maxval, seed=seed1, seed2=seed2, name=name)
#     308 else:
# --> 309   result = gen_random_ops.random_uniform(
#     310       shape, dtype, seed=seed1, seed2=seed2)
#     311   if minval_is_zero:
#     312     if not maxval_is_one:
#
# File /opt/conda/lib/python3.9/site-packages/tensorflow/python/ops/gen_random_ops.py:721, in random_uniform(shape, dtype, seed, seed2, name)
#     719   return _result
#     720 except _core._NotOkStatusException as e:
# --> 721   _ops.raise_from_not_ok_status(e, name)
#     722 except _core._FallbackException:
#     723   pass
#
# File /opt/conda/lib/python3.9/site-packages/tensorflow/python/framework/ops.py:6941, in raise_from_not_ok_status(e, name)
#    6939 message = e.message + (" name: " + name if name is not None else "")
#    6940 # pylint: disable=protected-access
# -> 6941 six.raise_from(core._status_to_exception(e.code, message), None)
#
# File <string>:3, in raise_from(value, from_value)
#
# ResourceExhaustedError: OOM when allocating tensor with shape[200704,1024] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc [Op:RandomUniform]

# %% [markdown]
# ``Compile model``

# %% [markdown]
# The next step is to compile the model. We have to decide on the type of optimizer, loss function, and metrics to compute.
#
# We will use the Adam optimizer for this assignment, the most popular gradient-based optimization algorithm. There are a few other choices, and you can read more [here](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers). The loss (cost) function suitable for our binary classification model is [binary_crossentropy](https://www.tensorflow.org/api_docs/python/tf/keras/losses). We will compute model accuracy on the training, validation and test datasets.

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True), #set from_ligits=True because our last layer does not apply sigmoid
              metrics=['accuracy'])

# %% [markdown]
# ``Fit model``

# %% [markdown]
# Finally, we will fit the model with 10 epochs on the train set and validate on the validation set. The performance depends on the current starter hyperparameters such as learning rate and choice of optimizer.

# %%
# set random seed to get reproductible results 
# neural network algorithms are stochastic (e.g., due to random weight initialization); setting a random seed helps to get more stable results after each run
# however, best way to deal with randomness is to repeat your experiment many times (30+) and use statistics to summarize the performance of the model
tf.random.set_seed(1234)
np.random.seed(1234)
history = model.fit(X_train, y_train,
                    epochs=10, 
                    validation_data=(X_val, y_val)
)

# %% [markdown]
# Next let's plot loss and accuracy for training and validation sets

# %%
hist = history.history
x_arr = np.arange(len(hist['loss'])) + 1

fig = plt.figure(figsize=(12, 4))
ax = fig.add_subplot(1, 2, 1)
ax.plot(x_arr, hist['loss'], '-o', label='Train loss')
ax.plot(x_arr, hist['val_loss'], '--<', label='Validation loss')
ax.legend(fontsize=15)
ax.set_xlabel('Epoch', size=15)
ax.set_ylabel('Loss', size=15)

ax = fig.add_subplot(1, 2, 2)
ax.plot(x_arr, hist['accuracy'], '-o', label='Train acc.')
ax.plot(x_arr, hist['val_accuracy'], '--<', label='Validation acc.')
ax.legend(fontsize=15)
ax.set_xlabel('Epoch', size=15)
ax.set_ylabel('Accuracy', size=15)
plt.show()

# %% [markdown]
# ## Show what the CNN model is learning after each layer

# %% [markdown]
# We will pick one example from our training data to visualize our CNN model's learning after each layer. Below we print the original image.

# %%
img_tensor = np.expand_dims(X_train[2], axis = 0);

# Print image tensor shape
print('Shape of image:', img_tensor.shape);
  
# Print image
plt.imshow(img_tensor[0]);
plt.title('label:' + str(y_train[1]))
plt.show()

# %% [markdown]
# Next we print what the model learns after each layer-channel. It's important to pay attention to the shape of the output image to understand what each layer does to the original input.

# %%
# outputs of the first 4 layers, which include conv2D and max pooling layers
layer_outputs = [layer.output for layer in model.layers[:4]]
activation_model = models.Model(inputs = model.input, outputs = layer_outputs)
activations = activation_model.predict(img_tensor)

# grab layer names
layer_names = []
for layer in model.layers[:4]:
    layer_names.append(layer.name)

# getting activations of each layer
for idx, layer in enumerate(activations):
    if idx in (0,1,2,3):
        print('----------------')
        print('Geeting activations of layer',  idx+1, ':', layer_names[idx])
        activation = layer

        # shape of layer activation
        print('Images size is', activation.shape[1], 'x', activation.shape[2])
        print('Number of channels is', activation.shape[3])

        # print channels
        print('Printing channels:')
        
        # define nrows and ncols depending on number of channels
        if idx in (0,1):
            nrows, ncols = 4,8
        if idx in (2,3):
            nrows, ncols = 8,8

        # plots
        channel=0
        if idx in (0,1):
            f, axs = plt.subplots(nrows, ncols, figsize=(14,12))
        if idx in (2,3):
            f, axs = plt.subplots(nrows, ncols, figsize=(14,20))
            
        for i in range(nrows):
            for j in range(ncols):
                if i==0 and j==0:
                    channel=0
                else:
                    channel+=1

                axs[i,j].matshow(activation[0,:, :, channel], cmap ='viridis')
                axs[i,j].set(title=str(channel))
                #axs[i,j].axis('off') # pay attention to the range of x and y axis
        plt.show()

# %% [markdown]
# As you can see, initial layers are more interpretable and retain the majority of the features in the input image. As the level of the layer increases, features become less interpretable, they become more abstract and they identify features specific to the class leaving behind the general features of the image.

# %% [markdown]
# ## Evaluation

# %% [markdown]
# Evaluation is one of the most important parts of machine learning as it helps us determine how good our trained model is in predicting unseen data.
#
# Notice that (`X_test`, and `y_test`) were not used in the training part. It would be very bad practice to evaluate the model on the test set, and then return and update the model based on those results (then the test set is acting like just another validation set).

# %% [markdown]
# We will now use our test data to evaluate the performance (accuracy) of our CNN model on unseen data. Note that accuracy is the default metric if one compiles the model with the accuracy metric.

# %%
test_results = model.evaluate(X_test, y_test)
print('\nTest Acc. {:.2f}%'.format(test_results[1]*100))

# %% [markdown]
# `get predictions results in the form of class-membership probabilities`

# %% [markdown]
# In the following figure, you can see all the images in the test data along with their ground truth (GT) labels and the predicted probabiliy that they belong to class 1, 'Refer'

# %%
# transform logits to probabilities
pred_logits = model.predict(X_test)
probas = tf.sigmoid(pred_logits)
probas = probas.numpy().flatten()*100

# %%
# plot test data and associated predicred
fig = plt.figure(figsize=(20, 20))

for j, example in enumerate(X_test):
    ax = fig.add_subplot(8,4, j+1)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.imshow(array_to_img(example))
    if y_test[j]==0:
        label='no refer'
    else:
        label='refer'
    
    ax.text(
        0.5, -0.15, 
        'GT: {:s}\nPr(refer)={:.0f}%'.format(label, probas[j]), 
        size=16, 
        color='grey',
        horizontalalignment='center',
        verticalalignment='center', 
        transform=ax.transAxes)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ### Exercise 4 (8 points)

# %% [markdown]
# In this exercise, your task is to experiment with different hyperparameter values to see how sensitive the accuracy of our CNN model is.  In the table below, you will fill in `training and validation accuracy` results corresponding to the last epoch of the model fit.
#
# You will change one hyperparameter value at a time, as follows:
#
# * kernel size = 3 x 3
# * strides = 2 x 2
# * pool size = 3 x 3
# * learning rate = 0.01
# * optimizer = 'SGD'
# * image augmentation applied on the training data: (brightness (delta) = 0.1, contrast = 2, flip = no)
#
# Finally, comment on the CNN model specification that you are most satisfied with based on the accuracy achieved on the training and validation sets. For this specification, what is the accuracy of the test dataset?

# %% [markdown]
# *Written answer*:
#
# | Trining accuracy | Validation accuracy |  kernel size |  strides | pool size  |  learning rate | optimizer  | brightness (delta) |  contrast factor | flip_on_train  |
# |:-:                |:-:                  |:-:           |:-:       |:-:         |:-:             |:-:         |:-:                 |:-:               |:-:             |
# | 0.94              | 0.81                | 5,5          | 1,1      | 2,2        | 0.001          | Adam       | 0.3                | 3                | yes            |
# | ...               | ...                 | <font color="red">3,3</font>     | 1,1      | 2,2        | 0.001          | Adam       | 0.3                | 3                | yes            |
# | ...               | ...                 | 5,5          | <font color="red">2,2</font>  | 2,2        | 0.001          | Adam       | 0.3                | 3                | yes            |
# | ...               | ...                 | 5,5          | 1,1      | <font color="red">3,3</font>   | 0.001          | Adam       | 0.3                | 3                | yes            |
# | ...               | ...                 | 5,5          | 1,1      | 2,2        | <font color="red">0.01</font>       | Adam       | 0.3                | 3                | yes            |
# | ...               | ...                 | 5,5          | 1,1      | 2,2        | 0.001          |<font color="red">SGD</font>     | 0.3                | 3                | yes            |
# | ...               | ...                 | 5,5          | 1,1      | 2,2        | 0.001          | Adam       | <font color="red">0.1</font>            | 3                | yes            |
# | ...               | ...                 | 5,5          | 1,1      | 2,2        | 0.001          | Adam       | 0.3                | <font color="red">2</font>            | yes            |
# | ...               | ...                 | 5,5          | 1,1      | 2,2        | 0.001          | Adam       | 0.3                | 3                | <font color="red">no</font>         |

# %% [markdown]
# ---
